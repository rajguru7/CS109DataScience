# %% [markdown]
# # HW1: Who is the best singer ever? Rihanna or Mariah?

# %% [markdown]
# <img width=600 height=400 src="http://static.idolator.com/uploads/2015/02/rihanna-mariah.jpg"/>
#
# Billboard Magazine puts out a top 100 list of "singles" every week. Information from this list, as well as that from music sales, radio, and other sources is used to determine a top-100 "singles" of the year list. A **single** is typically one song, but sometimes can be two songs which are on one "single" record.
#
# In this homework you will scrape both Wikipedia and Billboard Magazine to try to understand how the public's taste in music has evolved. You will do this by learning about the best singers and groups from each year (distinguishing between the two groups) as determined by the Billboard top 100 charts. You will have to scrape the web pages, clean the data, and visualize the performance of the artists and their songs. Finally, you'll find some "features" which might predict performance on the year end charts from the weekly ones.
#
# (Image credit: http://www.idolator.com/7579645/rihanna-mariah-carey-vision-of-love-made-her-want-to-do-music)

# %% [markdown]
# ## **This homework is due Thursday 24th September, at 11:59PM.**

# %% [markdown]
# We will use the **LAST COMMIT** BEFORE 11:59PM on Thursday Sep 24th 2015, on the **hw1** branch, of your repository `cs109-students/githubusername-2015hw` as your submission.

# %% [markdown]
# The homework will help develop your skills in:
#
# - web page scraping
# - data cleaning and manipulation
# - pandas
# - simple exploratory data visualization
# - thinking about data and what features might be used to make predictions
#
# You should have worked through Lab 1 (the pandas and python parts) and Lab 2.
#
# The table of contents below shows youthe structure of the homework. The headings with numbers like 1.2 and 3.2 are the ones that need to be answered. At lot of code is provided for you in this homework. DO NOT simply run it. Understand it. I promise that if you dont, you will have trouble in the parts that you have to code.
#
# Finally, start soon. This is not a very long homework, but we are at the point in the semester that logistical issues like git flow and python running might hold you up.

# %% [markdown]
# #Table of Contents
# * [HW1: Who is the best singer ever? Rihanna or Mariah?](#HW1:-Who-is-the-best-singer-ever?-Rihanna-or-Mariah?)
# 	* [**This homework is due Thursday 24th September, at 11:59PM.**](#**This-homework-is-due-Thursday-24th-September,-at-11:59PM.**)
# 	* [Q1. Scraping Wikipedia for Billboard Top 100.](#Q1.-Scraping-Wikipedia-for-Billboard-Top-100.)
# 		* [Scraping Wikipedia for Billboard singles](#Scraping-Wikipedia-for-Billboard-singles)
# 			* [Parsing the Billboard Wikipedia page for 1970](#Parsing-the-Billboard-Wikipedia-page-for-1970)
# 			* [1.1 Generalize the previous: Scrape wikipedia from 1992 to 2014](#1.1-Generalize-the-previous:-Scrape-wikipedia-from-1992-to-2014)
# 			* [1.2 Clean data and save a json file of information from the scraped files](#1.2-Clean-data-and-save-a-json-file-of-information-from-the-scraped-files)
# 		* [Construct a year-song-singer dataframe from the yearly information](#Construct-a-year-song-singer-dataframe-from-the-yearly-information)
# 			* [Construct a panel and flatten it](#Construct-a-panel-and-flatten-it)
# 			* [Cleaning data: the correct datatypes](#Cleaning-data:-the-correct-datatypes)
# 	* [Q2. Scraping and Constructing: Information about Artists, Bands and Genres from Wikipedia](#Q2.-Scraping-and-Constructing:-Information-about-Artists,-Bands-and-Genres-from-Wikipedia)
# 		* [Scrape information about artists from wikipedia](#Scrape-information-about-artists-from-wikipedia)
# 			* [Pulling and saving the data](#Pulling-and-saving-the-data)
# 			* [2.1 Extract information about singers and bands](#2.1-Extract-information-about-singers-and-bands)
# 			* [Merging this information in](#Merging-this-information-in)
# 			* [2.2 Split out the genres](#2.2-Split-out-the-genres)
# 	* [Q3. Exploratory Data Analysis (EDA)](#Q3.-Exploratory-Data-Analysis-%28EDA%29)
# 		* [What has been the trajectory of various genres in the popular zeitgeist?](#What-has-been-the-trajectory-of-various-genres-in-the-popular-zeitgeist?)
# 			* [3.1 Plot a horizontal bar chart of the top 30 genres](#3.1-Plot-a-horizontal-bar-chart-of-the-top-30-genres)
# 			* [3.2 Make a small multiples plot of the 24 most popular genres](#3.2-Make-a-small-multiples-plot-of-the-24-most-popular-genres)
# 		* [Who are the highest quality singers?](#Who-are-the-highest-quality-singers?)
# 			* [3.3 What if we used a different metric?](#3.3-What-if-we-used-a-different-metric?)
# 			* [The age at which singers achieve their top ranking.](#The-age-at-which-singers-achieve-their-top-ranking.)
# 			* [3.4 At what year since inception do bands reach their top rankings?](#3.4-At-what-year-since-inception-do-bands-reach-their-top-rankings?)
# 	* [Q4: Billboard Magazine: year end results from weekly results](#Q4:-Billboard-Magazine:-year-end-results-from-weekly-results)
# 		* [Get the end year results, and results from all saturdays of the year.](#Get-the-end-year-results,-and-results-from-all-saturdays-of-the-year.)
# 			* [Get the data](#Get-the-data)
# 			* [4.1 Parse the HTML and save the song information](#4.1-Parse-the-HTML-and-save-the-song-information)
# 		* [Get winning songs, and see how they do in all these weeks](#Get-winning-songs,-and-see-how-they-do-in-all-these-weeks)
# 			* [4.2 Plot the mean rank(y axis) against the final, year-end rank(x-axis)](#4.2-Plot-the-mean-rank%28y-axis%29-against-the-final,-year-end-rank%28x-axis%29)
# 		* [Add losers in and see what features may be used to distinguish winners from losers](#Add-losers-in-and-see-what-features-may-be-used-to-distinguish-winners-from-losers)
# 			* [4.3 Make a scatterplot matrix of these features, color coded by winners/losers](#4.3-Make-a-scatterplot-matrix-of-these-features,-color-coded-by-winners/losers)

# %% [markdown]
# ---

# %% [markdown]
# Python depends on packages for most of its functionality; these can be either built-in (such as sys), or third-party (like all the packages below). Either way you need to import the packages you need before using them.

# %%
# The %... is an iPython thing, and is not part of the Python language.
# In this case we're just telling the plotting library to draw things on
# the notebook, instead of on a separate window.
# %matplotlib inline
# See all the "as ..." contructs? They're just aliasing the package names.
# That way we can call methods like plt.plot() instead of matplotlib.pyplot.plot().
import numpy as np
import scipy as sp
import matplotlib as mpl
import matplotlib.cm as cm
import matplotlib.pyplot as plt
import pandas as pd
import time
pd.set_option('display.width', 500)
pd.set_option('display.max_columns', 100)
pd.set_option('display.notebook_repr_html', True)
import seaborn as sns
sns.set_style("whitegrid")
sns.set_context("poster")

# %% [markdown]
# We use [Seaborn](http://stanford.edu/~mwaskom/software/seaborn/) to give us a nicer default color palette, with our plots being of large (`poster`) size and with a white-grid background. (see the code above).

# %% [markdown]
# ## Q1. Scraping Wikipedia for Billboard Top 100.

# %% [markdown]
# In this question you will scrape wikipedia for Billboard's top 100. You may use any python scraping software you like. We especially recommend Beautiful Soup and PyQuery.

# %% [markdown]
# ### Scraping Wikipedia for Billboard singles

# %% [markdown]
# We'll be using one of two libraries to transform HTML content into Python data structures. One is [BeautifulSoup](http://www.crummy.com/software/BeautifulSoup/) and the other is [PyQuery](https://pythonhosted.org/pyquery/).
#
# You can choose which one you want to use.
#
# PyQuery is recommended for people who have used [jQuery](https://jquery.com/) before, or who feel more comfortable using CSS selectors. BeautifulSoup on the other hand might be a better  fit for people who are familiar with Python. Either package will make the job of parsing HTML documents easier.

# %%
from pyquery import PyQuery as pq
from bs4 import BeautifulSoup
# The "requests" library makes working with HTTP requests easier
# than the built-in urllib libraries.
import requests

# %% [markdown]
# #### Parsing the Billboard Wikipedia page for 1970

# %% [markdown]
# We'll use python's `requests` module to obtain the web page at http://en.wikipedia.org/wiki/Billboard_Year-End_Hot_100_singles_of_1970. From this web page we'll extract the top 100 singles and their rankings. We'll then create a list of [dictionaries](https://docs.python.org/2/tutorial/datastructures.html#dictionaries), 100 of them to be precise, with entries like `{'url': '/wiki/Sugarloaf_(band)', 'ranking': 30, 'band_singer': 'Sugarloaf', 'title': 'Green-Eyed Lady'}`. If you look at that web page, you will see that there is a link for every song, from which you can get the `url` of the singer or band. We will use these links later to scrape information about the singer or band. From the listing we can also get the band or singer name `band_singer`, and `title` of the song.
#
# We start by making a [GET](http://www.w3schools.com/tags/ref_httpmethods.asp) request to pull in the Billboard page from Wikipedia. This is the equivalent of using your browser to visit the page.
#
# In fact, you should visit the link above right now and [look at the source code of the page in the developer tools](http://wickedlysmart.com/hfhtml5/devtools.html), so you can follow what we'll be doing in the next few lines (Hint: in Chrome you can just hit F12 to get the developer tools).

# %%
# here we access the webpage and download the content using requests
t1970=requests.get("http://en.wikipedia.org/wiki/Billboard_Year-End_Hot_100_singles_of_1970")

# %% [markdown]
# Next we will need to look for the HTML _tr_ (table row) element, but only the one that has a CSS class of _wikitable_. If you look at the page source, you'll see a construct like __class=wikitable__ on the table in question. But you will also notice that none of the _tr_ elements actually have the __class__ attribute set directly on them.
#
# A full depth treatment of [CSS](http://www.w3schools.com/css/) [selectors](http://www.w3schools.com/cssref/css_selectors.asp) are beyond the scope of this course, but you just need to learn enough to enable you to scrape. For now you can think of it this way: children (embedded) elements inherit style properties from their parents, unless they have the property explicitly reset on their tag attributes.
#
# Here is a screenshot of that page with the developer tools opened in Safari. I clicked Inspect and then the word "Title" to make this appear.
#
# ![1970 songs](wikipage.png)

# %% [markdown]
# **_Read this if you would like to use pyquery_** . Otherwise, skip down a bit to the part where we use beautifulSoup.
#
# When you request a web page, the HTTP server on the other side of the connection sends a lot of meta-information along with the page content your browser renders. Because we are only interested in the page content (i.e. the HTML elements), we request the _text_ property of the request result (the lack of parenthesis after _text_ is a hint that we're asking the object for a property, and not calling a method).

# %%
d_=pq(t1970.text)

# %% [markdown]
# That text is then parsed by PyQuery (which was aliased as pq) and the result is bound to the _d\__ variable. The naming choice here is to mimic jQuery's \$ variable. Python is very flexible with identifier names for variables, functions, etc. They can't start with numbers, and underscores at the start and end of the name are somewhat special, but otherwise you have a lot of freedom naming them. Python is case sensitive, so my_var is different from My_var, which is different from MY_VAR, etc. Also, don't use Python [keywords](https://docs.python.org/2/reference/lexical_analysis.html#keywords) or built-in function names for your variables and functions. Weird things can happen if you do...
#
# The construct below generates a list like structure of _tr_ elements. The __[1:]__ part at the end means that we are only interested elements from the second position to the end of the list (in Python, indexes start at zero); that is because the first _tr_ element actually holds the table header.

# %%
d_rows=pq(d_('.wikitable tr')[1:])

# %% [markdown]
# Next we'll be calling the _text_ method of the PyQuery object, which will return the text between the opening and closing _tr_ tags. Note that as with the _requests_ response, this object contains a lot more information about the elements than just the text, which is why we need to explicitly tell it we only want the latter.
#
# You might have noticed that when we wanted the text content of the HTTP request we accessed its _text_ property, but this time we called the _text_ method (the parenthesis after the property name show that we're making a method call). Libraries are created by different people and are not always consistent. Please refer to the package documentation when in doubt.
#
# We will now parse the elements inside the _tr_ tags to get the data we need. I'll switch to inline comments to make it easier to follow the logic.

# %%
# Start by creating an empty list.
songs=[]

# Iterate over the elements of d_rows. In this case "r" will
# receive each value from "d_rows" in turn.
for r in d_rows:
    # Extract the "td" element from the current value of r.
    d_td=pq(r)('td')
    # Get the text from the first (index zero) "td" element, and convert
    # it to an integer. If you have the page open, this is the value on
    # the first column of the row (i.e. the song position on the chart).
    ranking = int(pq(d_td[0]).text())
    # The second column holds an "a" element, so we need to extract that
    # before getting the text data. This is the song title.
    title=pq(d_td[1])('a').text()
    # We then get the singer name, which is the text of the third column.
    band_singer=pq(d_td[2])('a').text()
    # Along with the singer name, we also want to get the URL to her Wikipedia page,
    # which is held on the "href" attribute of the a element.
    # Notice that we are still looking the same element we used to get the name (index 2).
    band_singer_url=pq(d_td[2])('a').attr.href
    # Next we'll place all this information on a dictionary (also called
    # a map, an associative array, a hash, etc.). We will use dictionaries
    # a lot, so it's worth to do some quick research on this versatil Python
    # structure.
    songdict=dict(ranking=ranking, title=title, band_singer=band_singer, url=band_singer_url)
    # Here we're just printing the dicitonary that was created during this iteration.
    # Lastly, we add the dictionary with the row information to the list we
    # created in the begining of the cell.
    # Lists will also be used extensively during the course, 
    # so you might as well do some reserach on it too.
    songs.append(songdict)

# %% [markdown]
# You should now have a nice list of dictionaries with all the information you needed from the Wikipedia page.

# %%
# By the way, indexes are open on the upper bound.
# So songs[2:4] will give us the third and fourth elements, but not the fifth.
songs[2:4]

# %% [markdown]
# ---
#
# **_Read this if you would like to use Beautiful Soup_**
#
# We will now show how to accomplish the same thing with BeautifulSoup. We will also take the opportunity to showcase a programming style called Functional Programming. This style is very useful to data manipulation, and it involves encapsulating your code into small, well contained functions which call each other. My way of working is to usually write my code first, after which I **refactor** pieces of code into functions which I can then reuse in the future. Functional programming is very useful and great to know, but can get some time to get used to. It is absolutely not a requirement for this class, but we would like you to know about it, and even if you don't write in this style yourself, to be able to understand your team mates code.
#
# If you find the following constructs confusing, feel free to ignore them for now. It should be noted that Python is not a functional language, but it does have some attributes that allow semi-functional programs to be created.
#
# If you want to read more about the `BeautifulSoup` functions we use, please have a look at the [documentation](http://www.crummy.com/software/BeautifulSoup/bs4/doc/).
#
# The construct in the line `rows = soup.find...` below generates a list like structure of _tr_ elements. The __[1:]__ part at the end means that we are only interested elements from the second position to the end of the list (in Python, indexes start at zero); that is because the first _tr_ element actually holds the table header.

# %%
# We'll just reuse the request object that was previously created to create a BeautifulSoup element.
# The latter will be the equivalent of the "d_" object we created before.
soup = BeautifulSoup(t1970.text, "html.parser")

# In this line we are looking for a single "table" element with a class of wikitable;
# and then looking for all the "tr" elements on that table (notice the find vs find_all calls).
# Even though the syntax is very different from PyQuery, the end result is similar.
rows = soup.find("table", attrs={"class": "wikitable"}).find_all("tr")[1:]

# We then define an anonymous (lambda) function whose job it is to act on
#each column's element in each row in the table. Lambda functions are very
# handy for functional programming, and the one below should be easy to follow.
# The function processes each field of the parameter r accordingly. It starts by
# transforming the first column into an integer; it then proceeds to getting the text
# from the second and third elements, and finally it gets the HTTP link of the third
# element, and returns all that in a list (notice the surrounding brackets).
# The function is then bound to the cleaner variable so it can be referenced later.
rem_nl = lambda text: text.replace("\n","")

cleaner = lambda r: [int(r[0].get_text()), r[1].get_text(), rem_nl(r[2].get_text()), r[2].find("a").get("href")]

#lambda functions are also excellent for defining one line math functions.
#e.g. radius = lambda x,y: np.sqrt(x*x + y*y)

# Next we'll create a list of names that will be used as dictionary keys.
fields = ["ranking", "title", "band_singer", "url"]

# We now use the lambda function to process each "td" element on a given row.
# the [... for ... in ...] construct is a list comprehension. They look weird at
# first but are amazingly useful and worth spending some time to learn.
# At a high level, thing of it as a one line "for loop" that aggregates the result
# of each iteration into a list. So once this line finished running, we will have a list
# of something.
#
# The dict function is another way to create a dictionary. One neat thing about it
# is that it accepts a list of key/value pairs that will be used to create said dictionary.
#
# But where are these key/value pairs coming from in here? From the zip function!
# The zip function will take multiple iterables (things that can be treated as a sequence)
# and combine them. An example might make it clearer:
#
# zip(["a", "b", "c"], [1, 2, 3]) evaluates to [("a", 1), ("b", 2), ("c", 3)]. It's like a zipper!!!
#
# Anyway, never mind the parenthesis around the pairs; they just show that the elements
# are grouped into tuples, which you can think of as lists that are immutable (they can't grow or shrink).
#
# So to recap: the zip function creates a list of pairs; which the dict function then uses
# to create a dictionary, using the first element of the pair as the key and the second as
# the value; and finally, the list comprehension iterates over each row element, and puts
# the result of each iteration on a list, which is then bound to the songs variable.
songs = [dict(zip(fields, cleaner(row.find_all("td")))) for row in rows]

# %% [markdown]
# The cell above has a lot of comments, but only 5 lines of Python code. Functional programs have a tendency to be more concise and, once you get the gist of it, easier to understand.

# %%
songs[2:4]
# Out:
# [{'band_singer': u'The Guess Who',
#   'ranking': 3,
#   'title': u'"American Woman"',
#   'url': u'/wiki/The_Guess_Who'},
#  {'band_singer': u'B.J. Thomas',
#   'ranking': 4,
#   'title': u'"Raindrops Keep Fallin\' on My Head"',
#   'url': u'/wiki/B.J._Thomas'}]

# %% [markdown]
# In the end, we have a list with the same contents as the one created by the PyQuery version. On the next section you will have to parse the tables for multiple years. Pick one of the approaches presented above and adapt it to solve that problem. Or come up with your own solution!

# %% [markdown]
# #### 1.1 Generalize the previous: Scrape wikipedia from 1992 to 2014

# %% [markdown]
# By visiting the urls similar to the ones for 1970, we can obtain the billboard top 100 for the years 1992 to 2014. Download these using `requests` and store the text from those requests in a dictionary called `yearstext`. This dictionary ought to have as its keys the years (as integers from 1992 to 2014), and as values corresponding to these keys the text of the page being fetched.
#
# You ought to sleep a second at the very least in-between fetching each web page: you do not want Wikipedia to think you are a marauding bot attempting to mount a denial-of-service attack.

# %% [markdown]
# *Here are some notes for how you may do this*:
#
# You can start by using [`range`](https://docs.python.org/2/library/functions.html#range) to create a list of numbers from 1992 to 2014 (in its simplest form the `range` function returns a list of numbers from 0 to the argument given minus one). On a side note, if you need to generate a huge list of numbers (over thousands of numbers), use the _xrange_ function instead.
#
# You can then use [string interpolation](https://docs.python.org/2/library/stdtypes.html#string-formatting) to request the page for each year from 1992 to 2014. These pages are added to a dictionary with the year as the key and the page text as the value.
#
# The `time.sleep` function can be used to wait one second between requests, otherwise Wikipedia might get mad at us.
#
# At the end of the cell below, the dictionary `yearstext` **must** be defined.

# %%
#your code here
yearstext = {}
for i in range(1992,2015):
    tyear = requests.get("https://en.wikipedia.org/wiki/Billboard_Year-End_Hot_100_singles_of_" + str(i))
    yearstext.update({i:tyear.text})
    time.sleep(1)

# %%
yearstext[1998]
# Out:
# u'<!DOCTYPE html>\n<html class="client-nojs" lang="en" dir="ltr">\n<head>\n<meta charset="UTF-8"/>\n<title>Billboard Year-End Hot 100 singles of 1998 - Wikipedia</title>\n<script>document.documentElement.className="client-js";RLCONF={"wgBreakFrames":!1,"wgSeparatorTransformTable":["",""],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","January","February","March","April","May","June","July","August","September","October","November","December"],"wgRequestId":"27784326-fc29-48a6-9ba8-e2421a9ddd94","wgCSPNonce":!1,"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":!1,"wgNamespaceNumber":0,"wgPageName":"Billboard_Year-End_Hot_100_singles_of_1998","wgTitle":"Billboard Year-End Hot 100 singles of 1998","wgCurRevisionId":974790688,"wgRevisionId":974790688,"wgArticleId":18913174,"wgIsArticle":!0,"wgIsRedirect":!1,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["1998 record charts","Billboard charts"],"wgPageContentLanguage":"en","wgPageContentModel":"wikitext","wgRelevantPageName":"Billboard_Year-End_Hot_100_singles_of_1998","wgRelevantArticleId":18913174,"wgIsProbablyEditable":!0,\n"wgRelevantPageIsProbablyEditable":!0,"wgRestrictionEdit":[],"wgRestrictionMove":[],"wgMediaViewerOnClick":!0,"wgMediaViewerEnabledByDefault":!0,"wgPopupsReferencePreviews":!1,"wgPopupsConflictsWithNavPopupGadget":!1,"wgVisualEditor":{"pageLanguageCode":"en","pageLanguageDir":"ltr","pageVariantFallbacks":"en"},"wgMFDisplayWikibaseDescriptions":{"search":!0,"nearby":!0,"watchlist":!0,"tagline":!1},"wgWMESchemaEditAttemptStepOversample":!1,"wgULSCurrentAutonym":"English","wgNoticeProject":"wikipedia","wgCentralAuthMobileDomain":!1,"wgEditSubmitButtonLabelPublish":!0,"wgULSPosition":"interlanguage","wgWikibaseItemId":"Q513318"};RLSTATE={"ext.globalCssJs.user.styles":"ready","site.styles":"ready","noscript":"ready","user.styles":"ready","ext.globalCssJs.user":"ready","user":"ready","user.options":"loading","ext.cite.styles":"ready","skins.vector.styles.legacy":"ready","jquery.tablesorter.styles":"ready","jquery.makeCollapsible.styles":"ready",\n"ext.visualEditor.desktopArticleTarget.noscript":"ready","ext.uls.interlanguage":"ready","ext.wikimediaBadges":"ready","wikibase.client.init":"ready"};RLPAGEMODULES=["ext.cite.ux-enhancements","site","mediawiki.page.ready","jquery.tablesorter","jquery.makeCollapsible","skins.vector.legacy.js","ext.gadget.ReferenceTooltips","ext.gadget.charinsert","ext.gadget.extra-toolbar-buttons","ext.gadget.refToolbar","ext.gadget.switcher","ext.centralauth.centralautologin","mmv.head","mmv.bootstrap.autostart","ext.popups","ext.visualEditor.desktopArticleTarget.init","ext.visualEditor.targetLoader","ext.eventLogging","ext.wikimediaEvents","ext.navigationTiming","ext.uls.compactlinks","ext.uls.interface","ext.cx.eventlogging.campaigns","ext.quicksurveys.init","ext.centralNotice.geoIP","ext.centralNotice.startUp"];</script>\n<script>(RLQ=window.RLQ||[]).push(function(){mw.loader.implement("user.options@1hzgi",function($,jQuery,require,module){/*@nomin*/mw.user.tokens.set({"patrolToken":"+\\\\","watchToken":"+\\\\","csrfToken":"+\\\\"});\n});});</script>\n<link rel="stylesheet" href="/w/load.php?lang=en&amp;modules=ext.cite.styles%7Cext.uls.interlanguage%7Cext.visualEditor.desktopArticleTarget.noscript%7Cext.wikimediaBadges%7Cjquery.makeCollapsible.styles%7Cjquery.tablesorter.styles%7Cskins.vector.styles.legacy%7Cwikibase.client.init&amp;only=styles&amp;skin=vector"/>\n<script async="" src="/w/load.php?lang=en&amp;modules=startup&amp;only=scripts&amp;raw=1&amp;skin=vector"></script>\n<meta name="ResourceLoaderDynamicStyles" content=""/>\n<link rel="stylesheet" href="/w/load.php?lang=en&amp;modules=site.styles&amp;only=styles&amp;skin=vector"/>\n<meta name="generator" content="MediaWiki 1.36.0-wmf.6"/>\n<meta name="referrer" content="origin"/>\n<meta name="referrer" content="origin-when-crossorigin"/>\n<meta name="referrer" content="origin-when-cross-origin"/>\n<meta property="o ...

# %% [markdown]
# #### 1.2 Clean data and save a json file of information from the scraped files

# %% [markdown]
# Remember the code you wrote to get data from 1970 which produces a list of dictionaries, one corresponding to each single? Write a function `parse_year(year, yeartextdict)` which takes the year, prints it out, gets the text for the year from the just created year text dictionary, and return a list of dictionaries for that year, with one dictionary for each single.
#
# The dictionaries **must** be of this form:
#
# ```
# {'band_singer': ['Brandy', 'Monica'],
#   'ranking': 2,
#   'song': ['The Boy Is Mine'],
#   'songurl': ['/wiki/The_Boy_Is_Mine_(song)'],
#   'titletext': '" The Boy Is Mine "',
#   'url': ['/wiki/Brandy_Norwood', '/wiki/Monica_(entertainer)']}
# ```

# %% [markdown]
# Notice that some singles might have multiple songs:
#
# ```
# {'band_singer': ['Jewel'],
#   'ranking': 2,
#   'song': ['Foolish Games', 'You Were Meant for Me'],
#   'songurl': ['/wiki/Foolish_Games',
#    '/wiki/You_Were_Meant_for_Me_(Jewel_song)'],
#   'titletext': '" Foolish Games " / " You Were Meant for Me "',
#   'url': ['/wiki/Jewel_(singer)']}
# ```

# %% [markdown]
# And some don't have a song URL:
#
# ```
# {'band_singer': [u'Nu Flavor'],
#   'ranking': 91,
#   'song': [u'Heaven'],
#   'songurl': [None],
#   'titletext': u'"Heaven"',
#   'url': [u'/wiki/Nu_Flavor']}
# ```

# %% [markdown]
# There are some additional issues this function must handle:
#
# 1. There can be more than one one `band_singer` as can be seen above (sometimes with a comma, sometimes with "featuring" in between). The best way to parse these is to look for the urls.
# 2. There can be 2 songs in a single, because of the way the industry works: there are 2 sided singles. See https://en.wikipedia.org/wiki/Billboard_Year-End_Hot_100_singles_of_1997 for example. You can find other examples in 1998 and 1999.
# 3. The `titletext` is the contents of the table cell, and retains the quotes that wikipedia puts on the single.
# 4. If no song anchor is found (see the 24th song in the above url), assume there is one song in the single, set `songurl` to [`None`] and the song name to the contents of the table cell with the quotes stripped (ie `song` is a one-element list with this the `titletext` stripped of its quotes).

# %%
"""
Function
--------
parse_year

Inputs
------
year: the year you want the singles for
ytextdixt: a dictionary with keys as integer years and values the downloaded web pages 
    from wikipedia for that year.
   
Returns
-------

a list of dictionaries, each of which corresponds to a single and has the
following data:

Eg:

{'band_singer': ['Brandy', 'Monica'],
  'ranking': 2,
  'song': ['The Boy Is Mine'],
  'songurl': ['/wiki/The_Boy_Is_Mine_(song)'],
  'titletext': '" The Boy Is Mine "',
  'url': ['/wiki/Brandy_Norwood', '/wiki/Monica_(entertainer)']}
  
A dictionary with the following data:
    band_singer: a list of bands/singers who made this single
    song: a list of the titles of songs on this single
    songurl: a list of the same size as song which has urls for the songs on the single 
        (see point 3 above)
    ranking: ranking of the single
    titletext: the contents of the table cell
    band_singer: a list of bands or singers on this single
    url: a list of wikipedia singer/band urls on this single: only put in the part 
        of the url from /wiki onwards
    

Notes
-----
See description and example above.
"""
#your code here
def clean(row):
    l = []
    band_singer = [singer.get_text() for singer in row[2].find_all("a")]
    url = [urls.get("href") for urls in row[2].find_all("a")]
    ranking = int(row[0].get_text())
    if not row[1].find_all("a"):
        songurl = [None]
    else:
        songurl = [songs.get("href") for songs in row[1].find_all("a")]
        
    titletext = row[1].get_text()
    
    song = titletext.split(" / ")
    song = [s.replace('"', "") for s in song]
    return [band_singer, ranking, song, songurl, titletext, url]
    
def parse_year(year, yeartextdict):
    soup = BeautifulSoup(yeartextdict[year],"html.parser")
    rows = soup.find("table", attrs = {"class":"wikitable"}).find_all("tr")[1:]
    feilds = ["band_singer", "ranking", "song", "songurl", "titletext", "url"]
    ans = [dict(zip(feilds,clean(row.find_all(["td","th"])))) for row in rows]
    return ans

# %%
soup = BeautifulSoup(yearstext[1997], "html.parser")
rows = soup.find("table", attrs = {"class":"wikitable"}).find_all("tr")[1:]
tds = rows[74].find_all(["td", "th"])
# [t.get("href") for t in tds[1].find_all("a")]
[urls.get("href") for urls in tds[2].find_all("a")]
[singer.get_text() for singer in tds[2].find_all("a")]
# Out:
# [u'Scarface', u'2Pac']

# %% [markdown]
# As a test, try the following:

# %%
parse_year(1997, yearstext)[:5]
# Out:
# [{'band_singer': [u'Elton John'],
#   'ranking': 1,
#   'song': [u'Something About the Way You Look Tonight',
#    u'Candle in the Wind 1997'],
#   'songurl': [u'/wiki/Something_About_the_Way_You_Look_Tonight',
#    u'/wiki/Candle_in_the_Wind_1997'],
#   'titletext': u'"Something About the Way You Look Tonight" / "Candle in the Wind 1997"',
#   'url': [u'/wiki/Elton_John']},
#  {'band_singer': [u'Jewel'],
#   'ranking': 2,
#   'song': [u'Foolish Games', u'You Were Meant for Me'],
#   'songurl': [u'/wiki/Foolish_Games',
#    u'/wiki/You_Were_Meant_for_Me_(Jewel_song)'],
#   'titletext': u'"Foolish Games" / "You Were Meant for Me"',
#   'url': [u'/wiki/Jewel_(singer)']},
#  {'band_singer': [u'Puff Daddy', u'Faith Evans', u'112'],
#   'ranking': 3,
#   'song': [u"I'll Be Missing You"],
#   'songurl': [u'/wiki/I%27ll_Be_Missing_You'],
#   'titletext': u'"I\'ll Be Missing You"',
#   'url': [u'/wiki/Sean_Combs', u'/wiki/Faith_Evans', u'/wiki/112_(band)']},
#  {'band_singer': [u'Toni Braxton'],
#   'ranking': 4,
#   'song': [u'Un-Break My Heart'],
#   'songurl': [u'/wiki/Un-Break_My_Heart'],
#   'titletext': u'"Un-Break My Heart"',
#   'url': [u'/wiki/Toni_Braxton']},
#  {'band_singer': [u'Puff Daddy', u'Mase'],
#   'ranking': 5,
#   'song': [u"Can't Nobody Hold Me Down"],
#   'songurl': [u'/wiki/Can%27t_Nobody_Hold_Me_Down'],
#   'titletext': u'"Can\'t Nobody Hold Me Down"',
#   'url': [u'/wiki/Sean_Combs', u'/wiki/Mase']}]

# %% [markdown]
# This should give the following. Notice that the year 1997 exercises the edge cases we talked about earlier.

# %% [raw]
# [{'band_singer': ['Elton John'],
#   'ranking': 1,
#   'song': ['Something About the Way You Look Tonight',
#    'Candle in the Wind 1997'],
#   'songurl': ['/wiki/Something_About_the_Way_You_Look_Tonight',
#    '/wiki/Candle_in_the_Wind_1997'],
#   'titletext': '" Something About the Way You Look Tonight " / " Candle in the Wind 1997 "',
#   'url': ['/wiki/Elton_John']},
#  {'band_singer': ['Jewel'],
#   'ranking': 2,
#   'song': ['Foolish Games', 'You Were Meant for Me'],
#   'songurl': ['/wiki/Foolish_Games',
#    '/wiki/You_Were_Meant_for_Me_(Jewel_song)'],
#   'titletext': '" Foolish Games " / " You Were Meant for Me "',
#   'url': ['/wiki/Jewel_(singer)']},
#  {'band_singer': ['Puff Daddy', 'Faith Evans', '112'],
#   'ranking': 3,
#   'song': ["I'll Be Missing You"],
#   'songurl': ['/wiki/I%27ll_Be_Missing_You'],
#   'titletext': '" I\'ll Be Missing You "',
#   'url': ['/wiki/Sean_Combs', '/wiki/Faith_Evans', '/wiki/112_(band)']},
#  {'band_singer': ['Toni Braxton'],
#   'ranking': 4,
#   'song': ['Un-Break My Heart'],
#   'songurl': ['/wiki/Un-Break_My_Heart'],
#   'titletext': '" Un-Break My Heart "',
#   'url': ['/wiki/Toni_Braxton']},
#  {'band_singer': ['Puff Daddy', 'Mase'],
#   'ranking': 5,
#   'song': ["Can't Nobody Hold Me Down"],
#   'songurl': ['/wiki/Can%27t_Nobody_Hold_Me_Down'],
#   'titletext': '" Can\'t Nobody Hold Me Down "',
#   'url': ['/wiki/Sean_Combs', '/wiki/Mase']}]

# %% [markdown]
# Then, let us store the information for each year in a dictionary `yearinfo` keyed by year.

# %%
yearinfo = {y:parse_year(y, yearstext) for y in range(1992, 2015)}

# %% [markdown]
# We would not want to lose all this work, so let's save the last data structure we created to disk. That way if you need to re-run sections 1.3 and beyond, you don't need to redo all these requests and parsing. Notice that we save into the `tempdata` folder. If you look at the `.gitignore` for this repository, you will see that files in `tempdata` are not committed...these are large files, and when you commit and push your homework, we do not need to see them...

# %%
import json

# %%
import os
os.getcwd()
# Out:
# '/Users/saurabhrajguru/Downloads/CS109DataScience/HWs/taebong-2015hw-hw1'

# %%
fd = open("/Users/saurabhrajguru/Downloads/CS109DataScience/tempdata/yearinfo.json","w")
json.dump(yearinfo, fd)
fd.close()

# %% [markdown]
# Now let's reload our JSON file into the yearinfo variable, just to be sure everything is working.

# %%
# Another way to deal with files. Has the advantage of closing the file for you.
del yearinfo
with open("/Users/saurabhrajguru/Downloads/CS109DataScience/tempdata/yearinfo.json", "r") as fd:
    yearinfo = json.load(fd)

# %%
yearinfo
# Out:
# {u'1992': [{u'band_singer': [u'Boyz II Men'],
#    u'ranking': 1,
#    u'song': [u'End of the Road'],
#    u'songurl': [u'/wiki/End_of_the_Road_(Boyz_II_Men_song)'],
#    u'titletext': u'"End of the Road"',
#    u'url': [u'/wiki/Boyz_II_Men']},
#   {u'band_singer': [u'Sir Mix-a-Lot'],
#    u'ranking': 2,
#    u'song': [u'Baby Got Back'],
#    u'songurl': [u'/wiki/Baby_Got_Back'],
#    u'titletext': u'"Baby Got Back"',
#    u'url': [u'/wiki/Sir_Mix-a-Lot']},
#   {u'band_singer': [u'Kris Kross'],
#    u'ranking': 3,
#    u'song': [u'Jump'],
#    u'songurl': [u'/wiki/Jump_(Kris_Kross_song)'],
#    u'titletext': u'"Jump"',
#    u'url': [u'/wiki/Kris_Kross']},
#   {u'band_singer': [u'Vanessa Williams'],
#    u'ranking': 4,
#    u'song': [u'Save the Best for Last'],
#    u'songurl': [u'/wiki/Save_the_Best_for_Last'],
#    u'titletext': u'"Save the Best for Last"',
#    u'url': [u'/wiki/Vanessa_L._Williams']},
#   {u'band_singer': [u'TLC'],
#    u'ranking': 5,
#    u'song': [u'Baby-Baby-Baby'],
#    u'songurl': [u'/wiki/Baby-Baby-Baby'],
#    u'titletext': u'"Baby-Baby-Baby"',
#    u'url': [u'/wiki/TLC_(band)']},
#   {u'band_singer': [u'Eric Clapton'],
#    u'ranking': 6,
#    u'song': [u'Tears in Heaven'],
#    u'songurl': [u'/wiki/Tears_in_Heaven'],
#    u'titletext': u'"Tears in Heaven"',
#    u'url': [u'/wiki/Eric_Clapton']},
#   {u'band_singer': [u'En Vogue'],
#    u'ranking': 7,
#    u'song': [u"My Lovin' (You're Never Gonna Get It)"],
#    u'songurl': [u'/wiki/My_Lovin%27_(You%27re_Never_Gonna_Get_It)'],
#    u'titletext': u'"My Lovin\' (You\'re Never Gonna Get It)"',
#    u'url': [u'/wiki/En_Vogue']},
#   {u'band_singer': [u'Red Hot Chili Peppers'],
#    u'ranking': 8,
#    u'song': [u'Under the Bridge'],
#    u'songurl': [u'/wiki/Under_the_Bridge'],
#    u'titletext': u'"Under the Bridge"',
#    u'url': [u'/wiki/Red_Hot_Chili_Peppers']},
#   {u'band_singer': [u'Color Me Badd'],
#    u'ranking': 9,
#    u'song': [u'All 4 Love'],
#    u'songurl': [u'/wiki/All_4_Love'],
#    u'titletext': u'"All 4 Love"',
#    u'url': [u'/wiki/Color_Me_Badd']},
#   {u'band_singer': [u'Jon Secada'],
#    u'ranking': 10,
#    u'song': [u'Just Another Day'],
#    u'songurl': [u'/wiki/Just_Another_Day_(Jon_Secada_song)'],
#    u'titletext': u'"Just Another Day"',
#    u'url': [u'/wiki/Jon_Secada']},
#   {u'band_singer': [u'Shanice'],
#    u'ranking': 11,
#    u'song': [u'I Love Your Smile'],
#    u'songurl': [u'/wiki/I_Love_Your_Smile'],
#    u'titletext': u'"I Love Your Smile"',
#    u'url': [u'/wiki/Shanice']},
#   {u'band_singer': [u'Mr. Big'],
#    u'ranking': 12,
#    u'song': [u'To Be with You'],
#    u'songurl': [u'/wiki/To_Be_with_You'],
#    u'titletext': u'"To Be with You"',
#    u'url': [u'/wiki/Mr._Big_(band)']},
#   {u'band_singer': [u'Right Said Fred'],
#    u'ranking': 13,
#    u'song': [u"I'm Too Sexy"],
#    u'songurl': [u'/wiki/I%27m_Too_Sexy'],
#    u'titletext': u'"I\'m Too Sexy"',
#    u'url': [u'/wiki/Right_Said_Fred']},
#   {u'band_singer': [u'Michael Jackson'],
#    u'ranking': 14,
#    u'song': [u'Black or White'],
#    u'songurl': [u'/wiki/Black_or_White'],
#    u'titletext': u'"Black or White"',
#    u'url': [u'/wiki/Michael_Jackson']},
#   {u'band_singer': [u'Billy Ray Cyrus'],
#    u'ranking': 15,
#    u'song': [u'Achy Breaky Heart'],
#    u'songurl': [u'/wiki/Achy_Breaky_Heart'],
#    u'titletext': u'"Achy Breaky Heart"',
#    u'url': [u'/wiki/Billy_Ray_Cyrus']},
#   {u'band_singer': [u'Mariah Carey'],
#    u'ranking': 16,
#    u'song': [u"I'll Be There"],
#    u'songurl': [u'/wiki/I%27ll_Be_There_(The_Jackson_5_song)#Mariah_Carey_version'],
#    u'titletext': u'"I\'ll Be There"',
#    u'url': [u'/wiki/Mariah_Carey']},
#   {u'band_singer': [u"Guns N' Roses"],
#    u'ranking': 17,
#    u'song': [u'November Rain'],
#    u'songurl': [u'/wiki/November_Rain'],
#    u'titletext': u'"November Rain"',
#    u'url': [u'/wiki/Guns_N%27_Roses']},
#   {u'band_singer': [u'Tom Cochrane'],
#    u'ranking': 18,
#    u'song': [u'Life Is a Highway'],
#    u'songurl': [u'/wiki/Life_Is_a_Highway'],
#    u'titletext': u'"Life Is a Highway"',
#    u'url': [u'/wiki/Tom_Cochrane']},
#   {u'band_singer': [u'Michael Jackson'],
#    u'ranking': 19,
#    u'song': [u'Remember the Time'],
#    u'songurl': [u'/wiki/Remember_the_Time'],
#    u'titletext': u'"Remember the Time"',
#    u'url': [u'/wiki/Michael_Jackson']},
#   {u'band_singer': [u'CeCe Peniston'],
#    u'ranking': 20,
#    u'song': [u'Finally'],
#    u'songurl': [u'/wiki/Finally_(CeCe_Peniston_song)'],
#    u'titletext': u'"Finally"',
#    u'url': [u'/wiki/CeCe_Peniston']},
#   {u'band_singer': [u'Madonna'],
#    u'ranking': 21,
#    u'song': [u'This Used to Be My Playground'],
#    u'songurl': [u'/wiki/This_Used_to_Be_My_Playground'],
#    u'titletext': u'"This Used to Be My Playground"',
#    u'url': [u'/wiki/Madonna']},
#   {u'band_singer': [u'Patty Smyth', u'Don Henley'],
#    u'ranking': 22,
#    u'song': [u"Sometimes Love Just Ain't Enough"],
#    u'songurl': [u'/wiki/Sometimes_Love_Just_Ain%27t_Enough'],
#    u'titletext': u'"Sometimes Love Just Ain\'t Enough"',
#    u'url': [u'/wiki/Patty_Smyth', u'/wiki/Don_Henley']},
#   {u'band_singer': [u'Mariah Carey'],
#    u'ranking': 23,
#    u'song': [u"Can't Let Go"],
#    u'songurl': [u'/wiki/Can%27t_Let_Go_(Mariah_Carey_song)'],
#    u'titletext': u'"Can\'t Let Go"',
#    u'url': [u'/wiki/Mariah_Carey']},
#   {u'band_singer': [u'House of Pain'],
#    u'ranking': 24,
#    u'song': [u'Jump Around'],
#    u'songurl': [u'/wiki/Jump_Around'],
#    u'titletext': u'"Jump Around"',
#    u'url': [u'/wiki/House_of_Pain']},
#   {u'band_singer': [u'Prince', u'The New Power Generation'],
#    u'ranking': 25,
#    u'song': [u'Diamonds and Pearls'],
#    u'songurl': [u'/wiki/Diamonds_and_Pearls_(song)'],
#    u'titletext': u'"Diamonds and Pearls"',
#    u'url': [u'/wiki/Prince_(entertainer)', u'/wiki/The_New_Power_Generation']},
#   {u'band_singer': [u'George Michael', u'Elton John'],
#    u'ranking': 26,
#    u'song': [u"Don't Let the Sun Go Down on Me"],
#    u'songurl': [u'/wiki/Don%27t_Let_the_Sun_Go_Down_on_Me'],
#    u'titletext': u'"Don\'t Let the Sun Go Down on Me"',
#    u'url': [u'/wiki/George_Michael', u'/wiki/Elton_John']},
#   {u'band_singer': [u'Atlantic Starr'],
#    u'ranking': 27,
#    u'song': [u'Masterpiece'],
#    u'songurl': [u'/wiki/Masterpiece_(Atlantic_Starr_song)'],
#    u'titletext': u'"Masterpiece"',
#    u'url': [u'/wiki/Atlantic_Starr']},
#   {u'band_singer': [u'Celine Dion'],
#    u'ranking': 28,
#    u'song': [u'If You Asked Me To'],
#    u'songurl': [u'/wiki/If_You_Asked_Me_To'],
#    u'titletext': u'"If You Asked Me To"',
#    u'url': [u'/wiki/Celine_Dion']},
#   {u'band_singer': [u'En Vogue'],
#    u'ranking': 29,
#    u'song': [u'Giving Him Something He Can Feel'],
#    u'songurl': [u'/wiki/Something_He_Can_Feel'],
#    u'titletext': u'"Giving Him Something He Can Feel"',
#    u'url': [u'/wiki/En_Vogue']},
#   {u'band_singer': [u'Joe Public'],
#    u'ranking': 30,
#    u'song': [u'Live and Learn'],
#    u'songurl': [u'/wiki/Live_and_Learn_(Joe_Public_song)'],
#    u'titletext': u'"Live and Learn"',
#    u'url': [u'/wiki/Joe_Public_(band)']},
#   {u'band_singer': [u'Jodeci'],
#    u'ranking': 31,
#    u'song': [u'Come and Talk to Me'],
#    u'songurl': [u'/wiki/Come_and_Talk_to_Me'],
#    u'titletext': u'"Come and Talk to Me"',
#    u'url': [u'/wiki/Jodeci']},
#   {u'band_singer': [u'Nirvana'],
#    u'ranking': 32,
#    u'song': [u'Smells Like Teen Spirit'],
#    u'songurl': [u'/wiki/Smells_Like_Teen_Spirit'],
#    u'titletext': u'"Smells Like Teen Spirit"',
#    u'url': [u'/wiki/Nirvana_(band)']},
#   {u'band_singer': [u'Bobby Brown'],
#    u'ranking': 33,
#    u'song': [u"Humpin' Around"],
#    u'songurl': [u'/wiki/Humpin%27_Around'],
#    u'titletext': u'"Humpin\' Around"',
#    u'url': [u'/wiki/Bobby_Brown']},
#   {u'band_singer': [u'Sophie B. Hawkins'],
#    u'ranking': 34,
#    u'song': [u'Damn I Wish I Was Your Lover'],
#    u'songurl': [u'/wiki/Damn_I_Wish_I_Was_Your_Lover'],
#    u'titletext': u'"Damn I Wish I Was Your Lover"',
#    u'url': [u'/wiki/Sophie_B._Hawkins']},
#   {u'band_singer': [u'Tevin Campbell'],
#    u'ranking': 35,
#    u'song': [u'Tell Me What You Want Me to Do'],
#    u'songurl': [u'/wiki/Tell_Me_What_You_Want_Me_to_Do'],
#    u'titletext': u'"Tell Me What You Want Me to Do"',
#    u'url': [u'/wiki/Tevin_Campbell']},
#   {u'band_singer': [u'TLC'],
#    u'ranking': 36,
#    u'song': [u"Ain't 2 Proud 2 Beg"],
#    u'songurl': [u'/wiki/Ain%27t_2_Proud_2_Beg'],
#    u'titletext': u'"Ain\'t 2 Proud 2 Beg"',
#    u'url': [u'/wiki/TLC_(band)']},
#   {u'band_singer': [u'Boyz II Men'],
#    u'ranking': 37,
#    u'song': [u"It's So Hard to Say Goodbye to Yesterday"],
#    u'songurl': [u'/wiki/It%27s_So_Hard_to_Say_Goodbye_to_Yesterday'],
#    u'titletext': u'"It\'s So Hard to Say Goodbye to Yesterday"',
#    u'url': [u'/wiki/Boyz_II_Men']},
#   {u'band_singer': [u'Technotronic', u'Ya Kid K'],
#    u'ranking': 38,
#    u'song': [u'Move This'],
#    u'songurl': [u'/wiki/Move_This'],
#    u'titletext': u'"Move This"',
#    u'url': [u'/wiki/Technotronic', u'/wiki/Ya_Kid_K']},
#   {u'band_singer': [u'Queen'],
#    u'ranking': 39,
#    u'song': [u'Bohemian Rhapsody'],
#    u'songurl': [u'/wiki/Bohemian_Rhapsody'],
#    u'titletext': u'"Bohemian Rhapsody"',
#    u'url': [u'/wiki/Queen_(band)']},
#   {u'band_singer': [u'Arrested Development'],
#    u'ranking': 40,
#    u'song': [u'Tennessee'],
#    u'songurl': [u'/wiki/Tennessee_(Arrested_Development_song)'],
#    u'titletext': u'"Tennessee"',
#    u'url': [u'/wiki/Arrested_Development_(group)']},
#   {u'band_singer': [u'Luther Vandross', u'Janet Jackson'],
#    u'ranking': 41,
#    u'song': [u'The Best Things in Life Are Free'],
#    u'songurl': [u'/wiki/The_Best_Things_in_Life_Are_Free'],
#    u'titletext': u'"The Best Things in Life Are Free"',
#    u'url': [u'/wiki/Luther_Vandross', u'/wiki/Janet_Jackson']},
#   {u'band_singer': [u'Mariah Carey'],
#    u'ranking': 42,
#    u'song': [u'Make It Happen'],
#    u'songurl': [u'/wiki/Make_It_Happen_(Mariah_Carey_song)'],
#    u'titletext': u'"Make It Happen"',
#    u'url': [u'/wiki/Mariah_Carey']},
#   {u'band_singer': [u'Elton John'],
#    u'ranking': 43,
#    u'song': [u'The One'],
#    u'songurl': [u'/wiki/The_One_(Elton_John_song)'],
#    u'titletext': u'"The One"',
#    u'url': [u'/wiki/Elton_John']},
#   {u'band_singer': [u'P.M. Dawn'],
#    u'ranking': 44,
#    u'song': [u'Set Adrift on Memory Bliss'],
#    u'songurl': [u'/wiki/Set_Adrift_on_Memory_Bliss'],
#    u'titletext': u'"Set Adrift on Memory Bliss"',
#    u'url': [u'/wiki/P.M._Dawn']},
#   {u'band_singer': [u'Shakespears Sister'],
#    u'ranking': 45,
#    u'song': [u'Stay'],
#    u'songurl': [u'/wiki/Stay_(Shakespears_Sister_song)'],
#    u'titletext': u'"Stay"',
#    u'url': [u'/wiki/Shakespears_Sister']},
#   {u'band_singer': [u'Hammer'],
#    u'ranking': 46,
#    u'song': [u'2 Legit 2 Quit'],
#    u'songurl': [u'/wiki/Too_Legit_to_Quit_(song)'],
#    u'titletext': u'"2 Legit 2 Quit"',
#    u'url': [u'/wiki/MC_Hammer']},
#   {u'band_singer': [u'KWS'],
#    u'ranking': 47,
#    u'song': [u"Please Don't Go"],
#    u'songurl': [u'/wiki/Please_Don%27t_Go_(KC_and_the_Sunshine_Band_song)#KWS_version'],
#    u'titletext': u'"Please Don\'t Go"',
#    u'url': [u'/wiki/KWS_(band)']},
#   {u'band_singer': [u'Mint Condition'],
#    u'ranking': 48,
#    u'song': [u"Breakin' My Heart (Pretty Brown Eyes)"],
#    u'songurl': [u'/wiki/Breakin%27_My_Heart_(Pretty_Brown_Eyes)'],
#    u'titletext': u'"Breakin\' My Heart (Pretty Brown Eyes)"',
#    u'url': [u'/wiki/Mint_Condition']},
#   {u'band_singer': [u'The Cover Girls'],
#    u'ranking': 49,
#    u'song': [u'Wishing on a Star'],
#    u'songurl': [u'/wiki/Wishing_on_a_Star'],
#    u'titletext': u'"Wishing on a Star"',
#    u'url': [u'/wiki/The_Cover_Girls']},
#   {u'band_singer': [u'Hi-Five'],
#    u'ranking': 50,
#    u'song': [u"She's Playing Hard to Get"],
#    u'songurl': [None],
#    u'titletext': u'"She\'s Playing Hard to Get"',
#    u'url': [u'/wiki/Hi-Five']},
#   {u'band_singer': [u'P.M. Dawn'],
#    u'ranking': 51,
#    u'song': [u"I'd Die Without You"],
#    u'songurl': [u'/wiki/I%27d_Die_Without_You'],
#    u'titletext': u'"I\'d Die Without You"',
#    u'url': [u'/wiki/P.M._Dawn']},
#   {u'band_singer': [u'Amy Grant'],
#    u'ranking': 52,
#    u'song': [u'Good for Me'],
#    u'songurl': [u'/wiki/Good_for_Me_(song)'],
#    u'titletext': u'"Good for Me"',
#    u'url': [u'/wiki/Amy_Grant']},
#   {u'band_singer': [u'Toad the Wet Sprocket'],
#    u'ranking': 53,
#    u'song': [u'All I Want'],
#    u'songurl': [u'/wiki/All_I_Want_(Toad_the_Wet_Sprocket_song)'],
#    u'titletext': u'"All I Want"',
#    u'url': [u'/wiki/Toad_the_Wet_Sprocket']},
#   {u'band_singer': [u'Michael Bolton'],
#    u'ranking': 54,
#    u'song': [u'When a Man Loves a Woman'],
#    u'songurl': [u'/wiki/When_a_Man_Loves_a_Woman_(song)'],
#    u'titletext': u'"When a Man Loves a Woman"',
#    u'url': [u'/wiki/Michael_Bolton']},
#   {u'band_singer': [u'Genesis'],
#    u'ranking': 55,
#    u'song': [u"I Can't Dance"],
#    u'songurl': [u'/wiki/I_Can%27t_Dance'],
#    u'titletext': u'"I Can\'t Dance"',
#    u'url': [u'/wiki/Genesis_(band)']},
#   {u'band_singer': [u'Richard Marx'],
#    u'ranking': 56,
#    u'song': [u'Hazard'],
#    u'songurl': [u'/wiki/Hazard_(song)'],
#    u'titletext': u'"Hazard"',
#    u'url': [u'/wiki/Richard_Marx']},
#   {u'band_singer': [u'U2'],
#    u'ranking': 57,
#    u'song': [u'Mysterious Ways'],
#    u'songurl': [u'/wiki/Mysterious_Ways_(song)'],
#    u'titletext': u'"Mysterious Ways"',
#    u'url': [u'/wiki/U2']},
#   {u'band_singer': [u'George Michael'],
#    u'ranking': 58,
#    u'song': [u'Too Funky'],
#    u'songurl': [u'/wiki/Too_Funky'],
#    u'titletext': u'"Too Funky"',
#    u'url': [u'/wiki/George_Michael']},
#   {u'band_singer': [u'The Heights'],
#    u'ranking': 59,
#    u'song': [u'How Do You Talk to an Angel'],
#    u'songurl': [u'/wiki/How_Do_You_Talk_to_an_Angel'],
#    u'titletext': u'"How Do You Talk to an Angel"',
#    u'url': [u'/wiki/The_Heights_(American_TV_series)']},
#   {u'band_singer': [u'U2'],
#    u'ranking': 60,
#    u'song': [u'One'],
#    u'songurl': [u'/wiki/One_(U2_song)'],
#    u'titletext': u'"One"',
#    u'url': [u'/wiki/U2']},
#   {u'band_singer': [u'CeCe Peniston'],
#    u'ranking': 61,
#    u'song': [u"Keep on Walkin'"],
#    u'songurl': [u'/wiki/Keep_on_Walkin%27_(song)'],
#    u'titletext': u'"Keep on Walkin\'"',
#    u'url': [u'/wiki/CeCe_Peniston']},
#   {u'band_singer': [u'Genesis'],
#    u'ranking': 62,
#    u'song': [u'Hold on My Heart'],
#    u'songurl': [u'/wiki/Hold_on_My_Heart'],
#    u'titletext': u'"Hold on My Heart"',
#    u'url': [u'/wiki/Genesis_(band)']},
#   {u'band_singer': [u'Karyn White'],
#    u'ranking': 63,
#    u'song': [u'The Way I Feel About You'],
#    u'songurl': [None],
#    u'titletext': u'"The Way I Feel About You"',
#    u'url': [u'/wiki/Karyn_White']},
#   {u'band_singer': [u'Celine Dion', u'Peabo Bryson'],
#    u'ranking': 64,
#    u'song': [u'Beauty and the Beast'],
#    u'songurl': [u'/wiki/Beauty_and_the_Beast_(Disney_song)'],
#    u'titletext': u'"Beauty and the Beast"',
#    u'url': [u'/wiki/Celine_Dion', u'/wiki/Peabo_Bryson']},
#   {u'band_singer': [u'Kris Kross'],
#    u'ranking': 65,
#    u'song': [u'Warm It Up'],
#    u'songurl': [u'/wiki/Warm_It_Up'],
#    u'titletext': u'"Warm It Up"',
#    u'url': [u'/wiki/Kris_Kross']},
#   {u'band_singer': [u'Michael Jackson'],
#    u'ranking': 66,
#    u'song': [u'In the Closet'],
#    u'songurl': [u'/wiki/In_the_Closet'],
#    u'titletext': u'"In the Closet"',
#    u'url': [u'/wiki/Michael_Jackson']},
#   {u'band_singer': [u'Arrested Development'],
#    u'ranking': 67,
#    u'song': [u'People Everyday'],
#    u'songurl': [u'/wiki/People_Everyday'],
#    u'titletext': u'"People Everyday"',
#    u'url': [u'/wiki/Arrested_Development_(group)']},
#   {u'band_singer': [u'Genesis'],
#    u'ranking': 68,
#    u'song': [u'No Son of Mine'],
#    u'songurl': [u'/wiki/No_Son_of_Mine'],
#    u'titletext': u'"No Son of Mine"',
#    u'url': [u'/wiki/Genesis_(band)']},
#   {u'band_singer': [u'Marky Mark and the Funky Bunch'],
#    u'ranking': 69,
#    u'song': [u'Wildside'],
#    u'songurl': [u'/wiki/Wildside_(Marky_Mark_and_the_Funky_Bunch_song)'],
#    u'titletext': u'"Wildside"',
#    u'url': [u'/wiki/Marky_Mark_and_the_Funky_Bunch']},
#   {u'band_singer': [u'Bryan Adams'],
#    u'ranking': 70,
#    u'song': [u'Do I Have to Say the Words?'],
#    u'songurl': [u'/wiki/Do_I_Have_to_Say_the_Words%3F'],
#    u'titletext': u'"Do I Have to Say the Words?"',
#    u'url': [u'/wiki/Bryan_Adams']},
#   {u'band_singer': [u'The Cure'],
#    u'ranking': 71,
#    u'song': [u"Friday I'm in Love"],
#    u'songurl': [u'/wiki/Friday_I%27m_in_Love'],
#    u'titletext': u'"Friday I\'m in Love"',
#    u'url': [u'/wiki/The_Cure']},
#   {u'band_singer': [u'Ugly Kid Joe'],
#    u'ranking': 72,
#    u'song': [u'Everything About You'],
#    u'songurl': [u'/wiki/Everything_About_You_(Ugly_Kid_Joe_song)'],
#    u'titletext': u'"Everything About You"',
#    u'url': [u'/wiki/Ugly_Kid_Joe']},
#   {u'band_singer': [u'Paula Abdul'],
#    u'ranking': 73,
#    u'song': [u'Blowing Kisses in the Wind'],
#    u'songurl': [u'/wiki/Blowing_Kisses_in_the_Wind'],
#    u'titletext': u'"Blowing Kisses in the Wind"',
#    u'url': [u'/wiki/Paula_Abdul']},
#   {u'band_singer': [u'Bryan Adams'],
#    u'ranking': 74,
#    u'song': [u"Thought I'd Died and Gone to Heaven"],
#    u'songurl': [u'/wiki/Thought_I%27d_Died_and_Gone_to_Heaven'],
#    u'titletext': u'"Thought I\'d Died and Gone to Heaven"',
#    u'url': [u'/wiki/Bryan_Adams']},
#   {u'band_singer': [u'Snap!'],
#    u'ranking': 75,
#    u'song': [u'Rhythm Is a Dancer'],
#    u'songurl': [u'/wiki/Rhythm_Is_a_Dancer'],
#    u'titletext': u'"Rhythm Is a Dancer"',
#    u'url': [u'/wiki/Snap!']},
#   {u'band_singer': [u'Hammer'],
#    u'ranking': 76,
#    u'song': [u'Addams Groove'],
#    u'songurl': [u'/wiki/Addams_Groove'],
#    u'titletext': u'"Addams Groove"',
#    u'url': [u'/wiki/MC_Hammer']},
#   {u'band_singer': [u'Michael Bolton'],
#    u'ranking': 77,
#    u'song': [u'Missing You Now'],
#    u'songurl': [u'/wiki/Missing_You_Now'],
#    u'titletext': u'"Missing You Now"',
#    u'url': [u'/wiki/Michael_Bolton']},
#   {u'band_singer': [u'N2Deep'],
#    u'ranking': 78,
#    u'song': [u'Back to the Hotel'],
#    u'songurl': [None],
#    u'titletext': u'"Back to the Hotel"',
#    u'url': [u'/wiki/N2Deep']},
#   {u'band_singer': [u'Kathy Troccoli'],
#    u'ranking': 79,
#    u'song': [u'Everything Changes'],
#    u'songurl': [None],
#    u'titletext': u'"Everything Changes"',
#    u'url': [u'/wiki/Kathy_Troccoli']},
#   {u'band_singer': [u'Def Leppard'],
#    u'ranking': 80,
#    u'song': [u'Have You Ever Needed Someone So Bad'],
#    u'songurl': [u'/wiki/Have_You_Ever_Needed_Someone_So_Bad'],
#    u'titletext': u'"Have You Ever Needed Someone So Bad"',
#    u'url': [u'/wiki/Def_Leppard']},
#   {u'band_singer': [u'Richard Marx'],
#    u'ranking': 81,
#    u'song': [u'Take This Heart'],
#    u'songurl': [u'/wiki/Take_This_Heart'],
#    u'titletext': u'"Take This Heart"',
#    u'url': [u'/wiki/Richard_Marx']},
#   {u'band_singer': [u'FireHouse'],
#    u'ranking': 82,
#    u'song': [u'When I Look Into Your Eyes'],
#    u'songurl': [u'/wiki/When_I_Look_Into_Your_Eyes'],
#    u'titletext': u'"When I Look Into Your Eyes"',
#    u'url': [u'/wiki/FireHouse_(band)']},
#   {u'band_singer': [u'Jade'],
#    u'ranking': 83,
#    u'song': [u'I Wanna Love You'],
#    u'songurl': [u'/wiki/I_Wanna_Love_You_(Jade_song)'],
#    u'titletext': u'"I Wanna Love You"',
#    u'url': [u'/wiki/Jade_(American_band)']},
#   {u'band_singer': [u'Boyz II Men'],
#    u'ranking': 84,
#    u'song': [u'Uhh Ahh'],
#    u'songurl': [u'/wiki/Uhh_Ahh'],
#    u'titletext': u'"Uhh Ahh"',
#    u'url': [u'/wiki/Boyz_II_Men']},
#   {u'band_singer': [u'Mary J. Blige'],
#    u'ranking': 85,
#    u'song': [u'Real Love'],
#    u'songurl': [u'/wiki/Real_Love_(Mary_J._Blige_song)'],
#    u'titletext': u'"Real Love"',
#    u'url': [u'/wiki/Mary_J._Blige']},
#   {u'band_singer': [u'The KLF'],
#    u'ranking': 86,
#    u'song': [u'Justified and Ancient'],
#    u'songurl': [u'/wiki/Justified_and_Ancient'],
#    u'titletext': u'"Justified and Ancient"',
#    u'url': [u'/wiki/The_KLF']},
#   {u'band_singer': [u'Color Me Badd'],
#    u'ranking': 87,
#    u'song': [u'Slow Motion'],
#    u'songurl': [None],
#    u'titletext': u'"Slow Motion"',
#    u'url': [u'/wiki/Color_Me_Badd']},
#   {u'band_singer': [u'TLC'],
#    u'ranking': 88,
#    u'song': [u'What About Your Friends'],
#    u'songurl': [u'/wiki/What_About_Your_Friends'],
#    u'titletext': u'"What About Your Friends"',
#    u'url': [u'/wiki/TLC_(band)']},
#   {u'band_singer': [u'Color Me Badd'],
#    u'ranking': 89,
#    u'song': [u"Thinkin' Back"],
#    u'songurl': [None],
#    u'titletext': u'"Thinkin\' Back"',
#    u'url': [u'/wiki/Color_Me_Badd']},
#   {u'band_singer': [u'Charles & Eddie'],
#    u'ranking': 90,
#    u'song': [u'Would I Lie to You?'],
#    u'songurl': [u'/wiki/Would_I_Lie_to_You%3F_(Charles_%26_Eddie_song)'],
#    u'titletext': u'"Would I Lie to You?"',
#    u'url': [u'/wiki/Charles_%26_Eddie']},
#   {u'band_singer': [u'Amy Grant'],
#    u'ranking': 91,
#    u'song': [u"That's What Love Is For"],
#    u'songurl': [u'/wiki/That%27s_What_Love_Is_For'],
#    u'titletext': u'"That\'s What Love Is For"',
#    u'url': [u'/wiki/Amy_Grant']},
#   {u'band_singer': [u'Richard Marx'],
#    u'ranking': 92,
#    u'song': [u'Keep Coming Back'],
#    u'songurl': [u'/wiki/Keep_Coming_Back_(song)'],
#    u'titletext': u'"Keep Coming Back"',
#    u'url': [u'/wiki/Richard_Marx']},
#   {u'band_singer': [u'En Vogue'],
#    u'ranking': 93,
#    u'song': [u'Free Your Mind'],
#    u'songurl': [u'/wiki/Free_Your_Mind_(song)'],
#    u'titletext': u'"Free Your Mind"',
#    u'url': [u'/wiki/En_Vogue']},
#   {u'band_singer': [u'Keith Sweat'],
#    u'ranking': 94,
#    u'song': [u"Keep It Comin'"],
#    u'songurl': [u'/wiki/Keep_It_Comin%27_(song)'],
#    u'titletext': u'"Keep It Comin\'"',
#    u'url': [u'/wiki/Keith_Sweat']},
#   {u'band_singer': [u'Mr. Big'],
#    u'ranking': 95,
#    u'song': [u'Just Take My Heart'],
#    u'songurl': [u'/wiki/Just_Take_My_Heart_(song)'],
#    u'titletext': u'"Just Take My Heart"',
#    u'url': [u'/wiki/Mr._Big_(band)']},
#   {u'band_singer': [u'Amy Grant'],
#    u'ranking': 96,
#    u'song': [u'I Will Remember You'],
#    u'songurl': [u'/wiki/I_Will_Remember_You_(Amy_Grant_song)'],
#    u'titletext': u'"I Will Remember You"',
#    u'url': [u'/wiki/Amy_Grant']},
#   {u'band_singer': [u'CeCe Peniston'],
#    u'ranking': 97,
#    u'song': [u'We Got a Love Thang'],
#    u'songurl': [u'/wiki/We_Got_a_Love_Thang'],
#    u'titletext': u'"We Got a Love Thang"',
#    u'url': [u'/wiki/CeCe_Peniston']},
#   {u'band_singer': [u'Def Leppard'],
#    u'ranking': 98,
#    u'song': [u"Let's Get Rocked"],
#    u'songurl': [u'/wiki/Let%27s_Get_Rocked'],
#    u'titletext': u'"Let\'s Get Rocked"',
#    u'url': [u'/wiki/Def_Leppard']},
#   {u'band_singer': [u'Das EFX'],
#    u'ranking': 99,
#    u'song': [u'They Want EFX'],
#    u'songurl': [u'/wiki/They_Want_EFX'],
#    u'titletext': u'"They Want EFX"',
#    u'url': [u'/wiki/Das_EFX']},
#   {u'band_singer': [u'Bonnie Raitt'],
#    u'ranking': 100,
#    u'song': [u"I Can't Make You Love Me"],
#    u'songurl': [u'/wiki/I_Can%27t_Make_You_Love_Me'],
#    u'titletext': u'"I Can\'t Make You Love Me"',
#    u'url': [u'/wiki/Bonnie_Raitt']}],
#  u'1993': [{u'band_singer': [u'Whitney Houston'],
#    u'ranking': 1,
#    u'song': [u'I Will Always Love You'],
#    u'songurl': [u'/wiki/I_Will_Always_Love_You#Whitney_Houston_version'],
#    u'titletext': u'"I Will Always Love You"',
#    u'url': [u'/wiki/Whitney_Houston']},
#   {u'band_singer': [u'Tag Team'],
#    u'ranking': 2,
#    u'song': [u'Whoomp! (There It Is)'],
#    u'songurl': [u'/wiki/Whoomp!_(There_It_Is)'],
#    u'titletext': u'"Whoomp! (There It Is)"',
#    u'url': [u'/wiki/Tag_Team_(group)']},
#   {u'band_singer': [u'UB40'],
#    u'ranking': 3,
#    u'song': [u"Can't Help Falling in Love"],
#    u'songurl': [u'/wiki/Can%27t_Help_Falling_in_Love'],
#    u'titletext': u'"Can\'t Help Falling in Love"',
#    u'url': [u'/wiki/UB40']},
#   {u'band_singer': [u'Janet Jackson'],
#    u'ranking': 4,
#    u'song': [u"That's the Way Love Goes"],
#    u'songurl': [u'/wiki/That%27s_the_Way_Love_Goes_(Janet_Jackson_song)'],
#    u'titletext': u'"That\'s the Way Love Goes"',
#    u'url': [u'/wiki/Janet_Jackson']},
#   {u'band_singer': [u'Silk'],
#    u'ranking': 5,
#    u'song': [u'Freak Me'],
#    u'songurl': [u'/wiki/Freak_Me'],
#    u'titletext': u'"Freak Me"',
#    u'url': [u'/wiki/Silk_(group)']},
#   {u'band_singer': [u'SWV'],
#    u'ranking': 6,
#    u'song': [u'Weak'],
#    u'songurl': [u'/wiki/Weak_(SWV_song)'],
#    u'titletext': u'"Weak"',
#    u'url': [u'/wiki/SWV']},
#   {u'band_singer': [u'Shai'],
#    u'ranking': 7,
#    u'song': [u'If I Ever Fall in Love'],
#    u'songurl': [u'/wiki/If_I_Ever_Fall_in_Love'],
#    u'titletext': u'"If I Ever Fall in Love"',
#    u'url': [u'/wiki/Shai_(band)']},
#   {u'band_singer': [u'Mariah Carey'],
#    u'ranking': 8,
#    u'song': [u'Dreamlover'],
#    u'songurl': [u'/wiki/Dreamlover_(song)'],
#    u'titletext': u'"Dreamlover"',
#    u'url': [u'/wiki/Mariah_Carey']},
#   {u'band_singer': [u'Wreckx-n-Effect'],
#    u'ranking': 9,
#    u'song': [u'Rump Shaker'],
#    u'songurl': [u'/wiki/Rump_Shaker_(song)'],
#    u'titletext': u'"Rump Shaker"',
#    u'url': [u'/wiki/Wreckx-n-Effect']},
#   {u'band_singer': [u'Snow'],
#    u'ranking': 10,
#    u'song': [u'Informer'],
#    u'songurl': [u'/wiki/Informer_(song)'],
#    u'titletext': u'"Informer"',
#    u'url': [u'/wiki/Snow_(musician)']},
#   {u'band_singer': [u'Dr. Dre'],
#    u'ranking': 11,
#    u'song': [u"Nuthin' but a 'G' Thang"],
#    u'songurl': [u'/wiki/Nuthin%27_but_a_%27G%27_Thang'],
#    u'titletext': u'"Nuthin\' but a \'G\' Thang"',
#    u'url': [u'/wiki/Dr._Dre']},
#   {u'band_singer': [u'Boyz II Men'],
#    u'ranking': 12,
#    u'song': [u'In the Still of the Nite'],
#    u'songurl': [u'/wiki/In_the_Still_of_the_Night_(1956_song)#Boyz_II_Men_version'],
#    u'titletext': u'"In the Still of the Nite"',
#    u'url': [u'/wiki/Boyz_II_Men']},
#   {u'band_singer': [u'Jade'],
#    u'ranking': 13,
#    u'song': [u"Don't Walk Away"],
#    u'songurl': [u'/wiki/Don%27t_Walk_Away_(Jade_song)'],
#    u'titletext': u'"Don\'t Walk Away"',
#    u'url': [u'/wiki/Jade_(R%26B_group)']},
#   {u'band_singer': [u'H-Town'],
#    u'ranking': 14,
#    u'song': [u"Knockin' da Boots"],
#    u'songurl': [u'/wiki/Knockin%27_da_Boots'],
#    u'titletext': u'"Knockin\' da Boots"',
#    u'url': [u'/wiki/H-Town_(band)']},
#   {u'band_singer': [u'Jodeci'],
#    u'ranking': 15,
#    u'song': [u'Lately'],
#    u'songurl': [u'/wiki/Lately_(Jodeci_song)'],
#    u'titletext': u'"Lately"',
#    u'url': [u'/wiki/Jodeci']},
#   {u'band_singer': [u'Duice'],
#    u'ranking': 16,
#    u'song': [u'Dazzey Duks'],
#    u'songurl': [u'/wiki/Dazzey_Duks'],
#    u'titletext': u'"Dazzey Duks"',
#    u'url': [u'/wiki/Duice']},
#   {u'band_singer': [u'Robin S.'],
#    u'ranking': 17,
#    u'song': [u'Show Me Love'],
#    u'songurl': [u'/wiki/Show_Me_Love_(Robin_S._song)'],
#    u'titletext': u'"Show Me Love"',
#    u'url': [u'/wiki/Robin_S.']},
#   {u'band_singer': [u'Peabo Bryson', u'Regina Belle'],
#    u'ranking': 18,
#    u'song': [u'A Whole New World'],
#    u'songurl': [u'/wiki/A_Whole_New_World'],
#    u'titletext': u'"A Whole New World"',
#    u'url': [u'/wiki/Peabo_Bryson', u'/wiki/Regina_Belle']},
#   {u'band_singer': [u'Janet Jackson'],
#    u'ranking': 19,
#    u'song': [u'If'],
#    u'songurl': [u'/wiki/If_(Janet_Jackson_song)'],
#    u'titletext': u'"If"',
#    u'url': [u'/wiki/Janet_Jackson']},
#   {u'band_singer': [u'SWV'],
#    u'ranking': 20,
#    u'song': [u"I'm So Into You"],
#    u'songurl': [u'/wiki/I%27m_So_Into_You'],
#    u'titletext': u'"I\'m So Into You"',
#    u'url': [u'/wiki/SWV']},
#   {u'band_singer': [u'Vanessa Williams', u'Brian McKnight'],
#    u'ranking': 21,
#    u'song': [u'Love Is'],
#    u'songurl': [u'/wiki/Love_Is_(Vanessa_Williams_song)'],
#    u'titletext': u'"Love Is"',
#    u'url': [u'/wiki/Vanessa_L._Williams', u'/wiki/Brian_McKnight']},
#   {u'band_singer': [u'Soul Asylum'],
#    u'ranking': 22,
#    u'song': [u'Runaway Train'],
#    u'songurl': [u'/wiki/Runaway_Train_(Soul_Asylum_song)'],
#    u'titletext': u'"Runaway Train"',
#    u'url': [u'/wiki/Soul_Asylum']},
#   {u'band_singer': [u'Expos\xe9'],
#    u'ranking': 23,
#    u'song': [u"I'll Never Get Over You (Getting Over Me)"],
#    u'songurl': [u'/wiki/I%27ll_Never_Get_Over_You_(Getting_Over_Me)'],
#    u'titletext': u'"I\'ll Never Get Over You (Getting Over Me)"',
#    u'url': [u'/wiki/Expos%C3%A9_(group)']},
#   {u'band_singer': [u'Paperboy'],
#    u'ranking': 24,
#    u'song': [u'Ditty'],
#    u'songurl': [u'/wiki/Ditty_(Paperboy_song)'],
#    u'titletext': u'"Ditty"',
#    u'url': [u'/wiki/Paperboy_(rapper)']},
#   {u'band_singer': [u'Snap!'],
#    u'ranking': 25,
#    u'song': [u'Rhythm Is a Dancer'],
#    u'songurl': [u'/wiki/Rhythm_Is_a_Dancer'],
#    u'titletext': u'"Rhythm Is a Dancer"',
#    u'url': [u'/wiki/Snap!']},
#   {u'band_singer': [u'Billy Joel'],
#    u'ranking': 26,
#    u'song': [u'The River of Dreams'],
#    u'songurl': [u'/wiki/The_River_of_Dreams'],
#    u'titletext': u'"The River of Dreams"',
#    u'url': [u'/wiki/Billy_Joel']},
#   {u'band_singer': [u'The Proclaimers'],
#    u'ranking': 27,
#    u'song': [u"I'm Gonna Be (500 Miles)"],
#    u'songurl': [u'/wiki/I%27m_Gonna_Be_(500_Miles)'],
#    u'titletext': u'"I\'m Gonna Be (500 Miles)"',
#    u'url': [u'/wiki/The_Proclaimers']},
#   {u'band_singer': [u'Spin Doctors'],
#    u'ranking': 28,
#    u'song': [u'Two Princes'],
#    u'songurl': [u'/wiki/Two_Princes'],
#    u'titletext': u'"Two Princes"',
#    u'url': [u'/wiki/Spin_Doctors']},
#   {u'band_singer': [u'SWV'],
#    u'ranking': 29,
#    u'song': [u'Right Here'],
#    u'songurl': [u'/wiki/Right_Here_(SWV_song)'],
#    u'titletext': u'"Right Here"',
#    u'url': [u'/wiki/SWV']},
#   {u'band_singer': [u'Whitney Houston'],
#    u'ranking': 30,
#    u'song': [u'I Have Nothing'],
#    u'songurl': [u'/wiki/I_Have_Nothing'],
#    u'titletext': u'"I Have Nothing"',
#    u'url': [u'/wiki/Whitney_Houston']},
#   {u'band_singer': [u'Arrested Development'],
#    u'ranking': 31,
#    u'song': [u'Mr. Wendal'],
#    u'songurl': [u'/wiki/Mr._Wendal'],
#    u'titletext': u'"Mr. Wendal"',
#    u'url': [u'/wiki/Arrested_Development_(group)']},
#   {u'band_singer': [u'Rod Stewart'],
#    u'ranking': 32,
#    u'song': [u'Have I Told You Lately'],
#    u'songurl': [u'/wiki/Have_I_Told_You_Lately'],
#    u'titletext': u'"Have I Told You Lately"',
#    u'url': [u'/wiki/Rod_Stewart']},
#   {u'band_singer': [u'Shanice'],
#    u'ranking': 33,
#    u'song': [u'Saving Forever for You'],
#    u'songurl': [u'/wiki/Saving_Forever_for_You'],
#    u'titletext': u'"Saving Forever for You"',
#    u'url': [u'/wiki/Shanice']},
#   {u'band_singer': [u'Duran Duran'],
#    u'ranking': 34,
#    u'song': [u'Ordinary World'],
#    u'songurl': [u'/wiki/Ordinary_World_(song)'],
#    u'titletext': u'"Ordinary World"',
#    u'url': [u'/wiki/Duran_Duran']},
#   {u'band_singer': [u'Tony! Toni! Ton\xe9!'],
#    u'ranking': 35,
#    u'song': [u'If I Had No Loot'],
#    u'songurl': [u'/wiki/If_I_Had_No_Loot'],
#    u'titletext': u'"If I Had No Loot"',
#    u'url': [u'/wiki/Tony!_Toni!_Ton%C3%A9!']},
#   {u'band_singer': [u'Meat Loaf'],
#    u'ranking': 36,
#    u'song': [u"I'd Do Anything for Love (But I Won't Do That)"],
#    u'songurl': [u'/wiki/I%27d_Do_Anything_for_Love_(But_I_Won%27t_Do_That)'],
#    u'titletext': u'"I\'d Do Anything for Love (But I Won\'t Do That)"',
#    u'url': [u'/wiki/Meat_Loaf']},
#   {u'band_singer': [u'Onyx'],
#    u'ranking': 37,
#    u'song': [u'Slam'],
#    u'songurl': [u'/wiki/Slam_(Onyx_song)'],
#    u'titletext': u'"Slam"',
#    u'url': [u'/wiki/Onyx_(hip_hop_group)']},
#   {u'band_singer': [u'P.M. Dawn'],
#    u'ranking': 38,
#    u'song': [u'Looking Through Patient Eyes'],
#    u'songurl': [u'/wiki/Looking_Through_Patient_Eyes'],
#    u'titletext': u'"Looking Through Patient Eyes"',
#    u'url': [u'/wiki/P.M._Dawn']},
#   {u'band_singer': [u'Whitney Houston'],
#    u'ranking': 39,
#    u'song': [u"I'm Every Woman"],
#    u'songurl': [u'/wiki/I%27m_Every_Woman#Whitney_Houston_version'],
#    u'titletext': u'"I\'m Every Woman"',
#    u'url': [u'/wiki/Whitney_Houston']},
#   {u'band_singer': [u'Shai'],
#    u'ranking': 40,
#    u'song': [u"Baby I'm Yours"],
#    u'songurl': [None],
#    u'titletext': u'"Baby I\'m Yours"',
#    u'url': [u'/wiki/Shai_(band)']},
#   {u'band_singer': [u'Duran Duran'],
#    u'ranking': 41,
#    u'song': [u'Come Undone'],
#    u'songurl': [u'/wiki/Come_Undone_(Duran_Duran_song)'],
#    u'titletext': u'"Come Undone"',
#    u'url': [u'/wiki/Duran_Duran']},
#   {u'band_singer': [u'Tina Turner'],
#    u'ranking': 42,
#    u'song': [u"I Don't Wanna Fight"],
#    u'songurl': [u'/wiki/I_Don%27t_Wanna_Fight'],
#    u'titletext': u'"I Don\'t Wanna Fight"',
#    u'url': [u'/wiki/Tina_Turner']},
#   {u'band_singer': [u'P.M. Dawn'],
#    u'ranking': 43,
#    u'song': [u"I'd Die Without You"],
#    u'songurl': [u'/wiki/I%27d_Die_Without_You'],
#    u'titletext': u'"I\'d Die Without You"',
#    u'url': [u'/wiki/P.M._Dawn']},
#   {u'band_singer': [u'95 South'],
#    u'ranking': 44,
#    u'song': [u'Whoot, There It Is'],
#    u'songurl': [u'/wiki/Whoot,_There_It_Is'],
#    u'titletext': u'"Whoot, There It Is"',
#    u'url': [u'/wiki/95_South']},
#   {u'band_singer': [u'Naughty by Nature'],
#    u'ranking': 45,
#    u'song': [u'Hip Hop Hooray'],
#    u'songurl': [u'/wiki/Hip_Hop_Hooray'],
#    u'titletext': u'"Hip Hop Hooray"',
#    u'url': [u'/wiki/Naughty_by_Nature']},
#   {u'band_singer': [u'Toni Braxton'],
#    u'ranking': 46,
#    u'song': [u'Another Sad Love Song'],
#    u'songurl': [u'/wiki/Another_Sad_Love_Song'],
#    u'titletext': u'"Another Sad Love Song"',
#    u'url': [u'/wiki/Toni_Braxton']},
#   {u'band_singer': [u'Michael Jackson'],
#    u'ranking': 47,
#    u'song': [u'Will You Be There'],
#    u'songurl': [u'/wiki/Will_You_Be_There'],
#    u'titletext': u'"Will You Be There"',
#    u'url': [u'/wiki/Michael_Jackson']},
#   {u'band_singer': [u'Shai'],
#    u'ranking': 48,
#    u'song': [u'Comforter'],
#    u'songurl': [u'/wiki/Comforter_(song)'],
#    u'titletext': u'"Comforter"',
#    u'url': [u'/wiki/Shai_(band)']},
#   {u'band_singer': [u'Bobby Brown'],
#    u'ranking': 49,
#    u'song': [u'Good Enough'],
#    u'songurl': [None],
#    u'titletext': u'"Good Enough"',
#    u'url': [u'/wiki/Bobby_Brown']},
#   {u'band_singer': [u'4 Non Blondes'],
#    u'ranking': 50,
#    u'song': [u"What's Up?"],
#    u'songurl': [u'/wiki/What%27s_Up%3F_(4_Non_Blondes_song)'],
#    u'titletext': u'"What\'s Up?"',
#    u'url': [u'/wiki/4_Non_Blondes']},
#   {u'band_singer': [u'Ace of Base'],
#    u'ranking': 51,
#    u'song': [u'All That She Wants'],
#    u'songurl': [u'/wiki/All_That_She_Wants'],
#    u'titletext': u'"All That She Wants"',
#    u'url': [u'/wiki/Ace_of_Base']},
#   {u'band_singer': [u'Prince', u'The New Power Generation'],
#    u'ranking': 52,
#    u'song': [u'7'],
#    u'songurl': [u'/wiki/7_(song)'],
#    u'titletext': u'"7"',
#    u'url': [u'/wiki/Prince_(musician)', u'/wiki/The_New_Power_Generation']},
#   {u'band_singer': [u'Dr. Dre', u'Snoop Doggy Dogg'],
#    u'ranking': 53,
#    u'song': [u'Dre Day'],
#    u'songurl': [u'/wiki/Fuck_wit_Dre_Day_(And_Everybody%27s_Celebratin%27)'],
#    u'titletext': u'"Dre Day"',
#    u'url': [u'/wiki/Dr._Dre', u'/wiki/Snoop_Dogg']},
#   {u'band_singer': [u'Brian McKnight'],
#    u'ranking': 54,
#    u'song': [u'One Last Cry'],
#    u'songurl': [u'/wiki/One_Last_Cry'],
#    u'titletext': u'"One Last Cry"',
#    u'url': [u'/wiki/Brian_McKnight']},
#   {u'band_singer': [u'Xscape'],
#    u'ranking': 55,
#    u'song': [u"Just Kickin' It"],
#    u'songurl': [u'/wiki/Just_Kickin%27_It'],
#    u'titletext': u'"Just Kickin\' It"',
#    u'url': [u'/wiki/Xscape_(band)']},
#   {u'band_singer': [u'2Pac'],
#    u'ranking': 56,
#    u'song': [u'I Get Around'],
#    u'songurl': [u'/wiki/I_Get_Around_(Tupac_Shakur_song)'],
#    u'titletext': u'"I Get Around"',
#    u'url': [u'/wiki/Tupac_Shakur']},
#   {u'band_singer': [u'Bon Jovi'],
#    u'ranking': 57,
#    u'song': [u'Bed of Roses'],
#    u'songurl': [u'/wiki/Bed_of_Roses_(Bon_Jovi_song)'],
#    u'titletext': u'"Bed of Roses"',
#    u'url': [u'/wiki/Bon_Jovi']},
#   {u'band_singer': [u'Mary J. Blige'],
#    u'ranking': 58,
#    u'song': [u'Real Love'],
#    u'songurl': [u'/wiki/Real_Love_(Mary_J._Blige_song)'],
#    u'titletext': u'"Real Love"',
#    u'url': [u'/wiki/Mary_J._Blige']},
#   {u'band_singer': [u'Portrait'],
#    u'ranking': 59,
#    u'song': [u'Here We Go Again!'],
#    u'songurl': [None],
#    u'titletext': u'"Here We Go Again!"',
#    u'url': [u'/wiki/Portrait_(band)']},
#   {u'band_singer': [u'Aerosmith'],
#    u'ranking': 60,
#    u'song': [u"Cryin'"],
#    u'songurl': [u'/wiki/Cryin%27'],
#    u'titletext': u'"Cryin\'"',
#    u'url': [u'/wiki/Aerosmith']},
#   {u'band_singer': [u'Ugly Kid Joe'],
#    u'ranking': 61,
#    u'song': [u"Cat's in the Cradle"],
#    u'songurl': [u'/wiki/Cat%27s_in_the_Cradle'],
#    u'titletext': u'"Cat\'s in the Cradle"',
#    u'url': [u'/wiki/Ugly_Kid_Joe']},
#   {u'band_singer': [u'TLC'],
#    u'ranking': 62,
#    u'song': [u'What About Your Friends'],
#    u'songurl': [u'/wiki/What_About_Your_Friends'],
#    u'titletext': u'"What About Your Friends"',
#    u'url': [u'/wiki/TLC_(group)']},
#   {u'band_singer': [u'Positive K'],
#    u'ranking': 63,
#    u'song': [u'I Got a Man'],
#    u'songurl': [u'/wiki/I_Got_a_Man'],
#    u'titletext': u'"I Got a Man"',
#    u'url': [u'/wiki/Positive_K']},
#   {u'band_singer': [u'Zhan\xe9'],
#    u'ranking': 64,
#    u'song': [u'Hey Mr. D.J.'],
#    u'songurl': [u'/wiki/Hey_Mr._D.J.'],
#    u'titletext': u'"Hey Mr. D.J."',
#    u'url': [u'/wiki/Zhan%C3%A9']},
#   {u'band_singer': [u'Cypress Hill'],
#    u'ranking': 65,
#    u'song': [u'Insane in the Brain'],
#    u'songurl': [u'/wiki/Insane_in_the_Brain'],
#    u'titletext': u'"Insane in the Brain"',
#    u'url': [u'/wiki/Cypress_Hill']},
#   {u'band_singer': [u'Madonna'],
#    u'ranking': 66,
#    u'song': [u'Deeper and Deeper'],
#    u'songurl': [u'/wiki/Deeper_and_Deeper'],
#    u'titletext': u'"Deeper and Deeper"',
#    u'url': [u'/wiki/Madonna']},
#   {u'band_singer': [u'Madonna'],
#    u'ranking': 67,
#    u'song': [u'Rain'],
#    u'songurl': [u'/wiki/Rain_(Madonna_song)'],
#    u'titletext': u'"Rain"',
#    u'url': [u'/wiki/Madonna']},
#   {u'band_singer': [u'Jeremy Jordan'],
#    u'ranking': 68,
#    u'song': [u'The Right Kind of Love'],
#    u'songurl': [u'/wiki/The_Right_Kind_of_Love'],
#    u'titletext': u'"The Right Kind of Love"',
#    u'url': [u'/wiki/Jeremy_Jordan_(singer,_born_1973)']},
#   {u'band_singer': [u'Inner Circle'],
#    u'ranking': 69,
#    u'song': [u'Bad Boys (theme from Cops)'],
#    u'songurl': [u'/wiki/Bad_Boys_(Inner_Circle_song)',
#     u'/wiki/Cops_(TV_series)'],
#    u'titletext': u'"Bad Boys" (theme from Cops)',
#    u'url': [u'/wiki/Inner_Circle_(reggae_band)']},
#   {u'band_singer': [u'Boy Krazy'],
#    u'ranking': 70,
#    u'song': [u"That's What Love Can Do"],
#    u'songurl': [u'/wiki/That%27s_What_Love_Can_Do'],
#    u'titletext': u'"That\'s What Love Can Do"',
#    u'url': [u'/wiki/Boy_Krazy']},
#   {u'band_singer': [u'Jon Secada'],
#    u'ranking': 71,
#    u'song': [u'Do You Believe in Us'],
#    u'songurl': [u'/wiki/Do_You_Believe_in_Us'],
#    u'titletext': u'"Do You Believe in Us"',
#    u'url': [u'/wiki/Jon_Secada']},
#   {u'band_singer': [u'Jon Secada'],
#    u'ranking': 72,
#    u'song': [u'Angel'],
#    u'songurl': [u'/wiki/Angel_(Jon_Secada_song)'],
#    u'titletext': u'"Angel"',
#    u'url': [u'/wiki/Jon_Secada']},
#   {u'band_singer': [u'Kenny G'],
#    u'ranking': 73,
#    u'song': [u'Forever in Love'],
#    u'songurl': [u'/wiki/Forever_in_Love_(instrumental)'],
#    u'titletext': u'"Forever in Love"',
#    u'url': [u'/wiki/Kenny_G']},
#   {u'band_singer': [u'Janet Jackson'],
#    u'ranking': 74,
#    u'song': [u'Again'],
#    u'songurl': [u'/wiki/Again_(Janet_Jackson_song)'],
#    u'titletext': u'"Again"',
#    u'url': [u'/wiki/Janet_Jackson']},
#   {u'band_singer': [u'DJ Jazzy Jeff & The Fresh Prince'],
#    u'ranking': 75,
#    u'song': [u'Boom! Shake the Room'],
#    u'songurl': [u'/wiki/Boom!_Shake_the_Room'],
#    u'titletext': u'"Boom! Shake the Room"',
#    u'url': [u'/wiki/DJ_Jazzy_Jeff_%26_The_Fresh_Prince']},
#   {u'band_singer': [u'Restless Heart'],
#    u'ranking': 76,
#    u'song': [u'When She Cries'],
#    u'songurl': [u'/wiki/When_She_Cries'],
#    u'titletext': u'"When She Cries"',
#    u'url': [u'/wiki/Restless_Heart']},
#   {u'band_singer': [u'Inner Circle'],
#    u'ranking': 77,
#    u'song': [u'Sweat (A La La La La Long)'],
#    u'songurl': [u'/wiki/Sweat_(A_La_La_La_La_Long)'],
#    u'titletext': u'"Sweat (A La La La La Long)"',
#    u'url': [u'/wiki/Inner_Circle_(reggae_band)']},
#   {u'band_singer': [u'Ice Cube'],
#    u'ranking': 78,
#    u'song': [u'It Was a Good Day'],
#    u'songurl': [u'/wiki/It_Was_a_Good_Day'],
#    u'titletext': u'"It Was a Good Day"',
#    u'url': [u'/wiki/Ice_Cube']},
#   {u'band_singer': [u'Captain Hollywood Project'],
#    u'ranking': 79,
#    u'song': [u'More and More'],
#    u'songurl': [u'/wiki/More_and_More_(Captain_Hollywood_Project_song)'],
#    u'titletext': u'"More and More"',
#    u'url': [u'/wiki/Captain_Hollywood_Project']},
#   {u'band_singer': [u'The Heights'],
#    u'ranking': 80,
#    u'song': [u'How Do You Talk to an Angel'],
#    u'songurl': [u'/wiki/How_Do_You_Talk_to_an_Angel'],
#    u'titletext': u'"How Do You Talk to an Angel"',
#    u'url': [u'/wiki/The_Heights_(American_TV_series)']},
#   {u'band_singer': [u'Digable Planets'],
#    u'ranking': 81,
#    u'song': [u'Rebirth of Slick (Cool Like Dat)'],
#    u'songurl': [u'/wiki/Rebirth_of_Slick_(Cool_Like_Dat)'],
#    u'titletext': u'"Rebirth of Slick (Cool Like Dat)"',
#    u'url': [u'/wiki/Digable_Planets']},
#   {u'band_singer': [u'Haddaway'],
#    u'ranking': 82,
#    u'song': [u'What Is Love'],
#    u'songurl': [u'/wiki/What_Is_Love_(Haddaway_song)'],
#    u'titletext': u'"What Is Love"',
#    u'url': [u'/wiki/Haddaway']},
#   {u'band_singer': [u'Michael Bolton'],
#    u'ranking': 83,
#    u'song': [u'To Love Somebody'],
#    u'songurl': [u'/wiki/To_Love_Somebody_(song)'],
#    u'titletext': u'"To Love Somebody"',
#    u'url': [u'/wiki/Michael_Bolton']},
#   {u'band_singer': [u'En Vogue'],
#    u'ranking': 84,
#    u'song': [u'Give It Up, Turn It Loose'],
#    u'songurl': [u'/wiki/Give_It_Up,_Turn_It_Loose'],
#    u'titletext': u'"Give It Up, Turn It Loose"',
#    u'url': [u'/wiki/En_Vogue']},
#   {u'band_singer': [u'Kris Kross'],
#    u'ranking': 85,
#    u'song': [u'Alright'],
#    u'songurl': [u'/wiki/Alright_(Kris_Kross_song)'],
#    u'titletext': u'"Alright"',
#    u'url': [u'/wiki/Kris_Kross']},
#   {u'band_singer': [u'Ice Cube', u'Das EFX'],
#    u'ranking': 86,
#    u'song': [u'Check Yo Self'],
#    u'songurl': [u'/wiki/Check_Yo_Self'],
#    u'titletext': u'"Check Yo Self"',
#    u'url': [u'/wiki/Ice_Cube', u'/wiki/Das_EFX']},
#   {u'band_singer': [u'Sting'],
#    u'ranking': 87,
#    u'song': [u'Fields of Gold'],
#    u'songurl': [u'/wiki/Fields_of_Gold'],
#    u'titletext': u'"Fields of Gold"',
#    u'url': [u'/wiki/Sting_(musician)']},
#   {u'band_singer': [u'Dino'],
#    u'ranking': 88,
#    u'song': [u'Ooh Child'],
#    u'songurl': [u'/wiki/Ooh_Child'],
#    u'titletext': u'"Ooh Child"',
#    u'url': [u'/wiki/Dino_(singer)']},
#   {u'band_singer': [u'Go West'],
#    u'ranking': 89,
#    u'song': [u'Faithful'],
#    u'songurl': [u'/wiki/Faithful_(Go_West_song)'],
#    u'titletext': u'"Faithful"',
#    u'url': [u'/wiki/Go_West_(band)']},
#   {u'band_singer': [u'Rod Stewart'],
#    u'ranking': 90,
#    u'song': [u'Reason to Believe'],
#    u'songurl': [u'/wiki/Reason_to_Believe'],
#    u'titletext': u'"Reason to Believe"',
#    u'url': [u'/wiki/Rod_Stewart']},
#   {u'band_singer': [u'Tears for Fears'],
#    u'ranking': 91,
#    u'song': [u'Break It Down Again'],
#    u'songurl': [u'/wiki/Break_It_Down_Again'],
#    u'titletext': u'"Break It Down Again"',
#    u'url': [u'/wiki/Tears_for_Fears']},
#   {u'band_singer': [u'Joey Lawrence'],
#    u'ranking': 92,
#    u'song': [u"Nothin' My Love Can't Fix"],
#    u'songurl': [u'/wiki/Nothin%27_My_Love_Can%27t_Fix'],
#    u'titletext': u'"Nothin\' My Love Can\'t Fix"',
#    u'url': [u'/wiki/Joey_Lawrence']},
#   {u'band_singer': [u'Green Jell\xff'],
#    u'ranking': 93,
#    u'song': [u'Three Little Pigs'],
#    u'songurl': [u'/wiki/Three_Little_Pigs_(song)'],
#    u'titletext': u'"Three Little Pigs"',
#    u'url': [u'/wiki/Green_Jell%C3%BF']},
#   {u'band_singer': [u'Aerosmith'],
#    u'ranking': 94,
#    u'song': [u"Livin' on the Edge"],
#    u'songurl': [u'/wiki/Livin%27_on_the_Edge'],
#    u'titletext': u'"Livin\' on the Edge"',
#    u'url': [u'/wiki/Aerosmith']},
#   {u'band_singer': [u'Gin Blossoms'],
#    u'ranking': 95,
#    u'song': [u'Hey Jealousy'],
#    u'songurl': [u'/wiki/Hey_Jealousy'],
#    u'titletext': u'"Hey Jealousy"',
#    u'url': [u'/wiki/Gin_Blossoms']},
#   {u'band_singer': [u'Sting'],
#    u'ranking': 96,
#    u'song': [u'If I Ever Lose My Faith in You'],
#    u'songurl': [u'/wiki/If_I_Ever_Lose_My_Faith_in_You'],
#    u'titletext': u'"If I Ever Lose My Faith in You"',
#    u'url': [u'/wiki/Sting_(musician)']},
#   {u'band_singer': [u'Tony! Toni! Ton\xe9!'],
#    u'ranking': 97,
#    u'song': [u'Anniversary'],
#    u'songurl': [u'/wiki/Anniversary_(Tony!_Toni!_Ton%C3%A9!_song)'],
#    u'titletext': u'"Anniversary"',
#    u'url': [u'/wiki/Tony!_Toni!_Ton%C3%A9!']},
#   {u'band_singer': [u'Jade'],
#    u'ranking': 98,
#    u'song': [u'One Woman'],
#    u'songurl': [u'/wiki/One_Woman'],
#    u'titletext': u'"One Woman"',
#    u'url': [u'/wiki/Jade_(American_band)']},
#   {u'band_singer': [u'Taylor Dayne'],
#    u'ranking': 99,
#    u'song': [u"Can't Get Enough of Your Love"],
#    u'songurl': [u'/wiki/Can%27t_Get_Enough_of_Your_Love#Taylor_Dayne_version'],
#    u'titletext': u'"Can\'t Get Enough of Your Love"',
#    u'url': [u'/wiki/Taylor_Dayne']},
#   {u'band_singer': [u'Def Leppard'],
#    u'ranking': 100,
#    u'song': [u'Two Steps Behind'],
#    u'songurl': [u'/wiki/Two_Steps_Behind'],
#    u'titletext': u'"Two Steps Behind"',
#    u'url': [u'/wiki/Def_Leppard']}],
#  u'1994': [{u'band_singer': [u'Ace of Base'],
#    u'ranking': 1,
#    u'song': [u'The Sign'],
#    u'songurl': [u'/wiki/The_Sign_(song)'],
#    u'titletext': u'"The Sign"',
#    u'url': [u'/wiki/Ace_of_Base']},
#   {u'band_singer': [u'All-4-One'],
#    u'ranking': 2,
#    u'song': [u'I Swear'],
#    u'songurl': [u'/wiki/I_Swear#All-4-One_version'],
#    u'titletext': u'"I Swear"',
#    u'url': [u'/wiki/All-4-One']},
#   {u'band_singer': [u'Boyz II Men'],
#    u'ranking': 3,
#    u'song': [u"I'll Make Love to You"],
#    u'songurl': [u'/wiki/I%27ll_Make_Love_to_You'],
#    u'titletext': u'"I\'ll Make Love to You"',
#    u'url': [u'/wiki/Boyz_II_Men']},
#   {u'band_singer': [u'C\xe9line Dion'],
#    u'ranking': 4,
#    u'song': [u'The Power of Love'],
#    u'songurl': [u'/wiki/The_Power_of_Love_(Jennifer_Rush_song)#C\xe9line_Dion_version'],
#    u'titletext': u'"The Power of Love"',
#    u'url': [u'/wiki/C%C3%A9line_Dion']},
#   {u'band_singer': [u'Mariah Carey'],
#    u'ranking': 5,
#    u'song': [u'Hero'],
#    u'songurl': [u'/wiki/Hero_(Mariah_Carey_song)'],
#    u'titletext': u'"Hero"',
#    u'url': [u'/wiki/Mariah_Carey']},
#   {u'band_singer': [u'Lisa Loeb and Nine Stories'],
#    u'ranking': 6,
#    u'song': [u'Stay (I Missed You)'],
#    u'songurl': [u'/wiki/Stay_(I_Missed_You)'],
#    u'titletext': u'"Stay (I Missed You)"',
#    u'url': [u'/wiki/Lisa_Loeb']},
#   {u'band_singer': [u'Toni Braxton'],
#    u'ranking': 7,
#    u'song': [u'Breathe Again'],
#    u'songurl': [u'/wiki/Breathe_Again'],
#    u'titletext': u'"Breathe Again"',
#    u'url': [u'/wiki/Toni_Braxton']},
#   {u'band_singer': [u'Bryan Adams', u'Rod Stewart', u'Sting'],
#    u'ranking': 8,
#    u'song': [u'All for Love'],
#    u'songurl': [u'/wiki/All_for_Love_(song)'],
#    u'titletext': u'"All for Love"',
#    u'url': [u'/wiki/Bryan_Adams',
#     u'/wiki/Rod_Stewart',
#     u'/wiki/Sting_(musician)']},
#   {u'band_singer': [u'Ace of Base'],
#    u'ranking': 9,
#    u'song': [u'All That She Wants'],
#    u'songurl': [u'/wiki/All_That_She_Wants'],
#    u'titletext': u'"All That She Wants"',
#    u'url': [u'/wiki/Ace_of_Base']},
#   {u'band_singer': [u'Ace of Base'],
#    u'ranking': 10,
#    u'song': [u"Don't Turn Around"],
#    u'songurl': [u'/wiki/Don%27t_Turn_Around'],
#    u'titletext': u'"Don\'t Turn Around"',
#    u'url': [u'/wiki/Ace_of_Base']},
#   {u'band_singer': [u'R. Kelly'],
#    u'ranking': 11,
#    u'song': [u"Bump n' Grind"],
#    u'songurl': [u'/wiki/Bump_n%27_Grind_(R._Kelly_song)'],
#    u'titletext': u'"Bump n\' Grind"',
#    u'url': [u'/wiki/R._Kelly']},
#   {u'band_singer': [u'Janet Jackson'],
#    u'ranking': 12,
#    u'song': [u'Again'],
#    u'songurl': [u'/wiki/Again_(Janet_Jackson_song)'],
#    u'titletext': u'"Again"',
#    u'url': [u'/wiki/Janet_Jackson']},
#   {u'band_singer': [u'Madonna'],
#    u'ranking': 13,
#    u'song': [u"I'll Remember"],
#    u'songurl': [u'/wiki/I%27ll_Remember'],
#    u'titletext': u'"I\'ll Remember"',
#    u'url': [u'/wiki/Madonna']},
#   {u'band_singer': [u'Salt-n-Pepa', u'En Vogue'],
#    u'ranking': 14,
#    u'song': [u'Whatta Man'],
#    u'songurl': [u'/wiki/Whatta_Man'],
#    u'titletext': u'"Whatta Man"',
#    u'url': [u'/wiki/Salt-n-Pepa', u'/wiki/En_Vogue']},
#   {u'band_singer': [u'John Mellencamp', u'Meshell Ndegeocello'],
#    u'ranking': 15,
#    u'song': [u'Wild Night'],
#    u'songurl': [u'/wiki/Wild_Night'],
#    u'titletext': u'"Wild Night"',
#    u'url': [u'/wiki/John_Mellencamp', u'/wiki/Meshell_Ndegeocello']},
#   {u'band_singer': [u'Mariah Carey'],
#    u'ranking': 16,
# ...
#    u'titletext': u'"Loyal"',
#    u'url': [u'/wiki/Chris_Brown',
#     u'/wiki/Lil_Wayne',
#     u'/wiki/French_Montana',
#     u'/wiki/Too_Short',
#     u'/wiki/Tyga']},
#   {u'band_singer': [u'American Authors'],
#    u'ranking': 31,
#    u'song': [u'Best Day of My Life'],
#    u'songurl': [u'/wiki/Best_Day_of_My_Life'],
#    u'titletext': u'"Best Day of My Life"',
#    u'url': [u'/wiki/American_Authors']},
#   {u'band_singer': [u'Tove Lo'],
#    u'ranking': 32,
#    u'song': [u'Habits (Stay High)'],
#    u'songurl': [u'/wiki/Habits_(Stay_High)'],
#    u'titletext': u'"Habits (Stay High)"',
#    u'url': [u'/wiki/Tove_Lo']},
#   {u'band_singer': [u'Calvin Harris'],
#    u'ranking': 33,
#    u'song': [u'Summer'],
#    u'songurl': [u'/wiki/Summer_(Calvin_Harris_song)'],
#    u'titletext': u'"Summer"',
#    u'url': [u'/wiki/Calvin_Harris']},
#   {u'band_singer': [u'Charli XCX'],
#    u'ranking': 34,
#    u'song': [u'Boom Clap'],
#    u'songurl': [u'/wiki/Boom_Clap'],
#    u'titletext': u'"Boom Clap"',
#    u'url': [u'/wiki/Charli_XCX']},
#   {u'band_singer': [u'Beyonc\xe9', u'Jay-Z'],
#    u'ranking': 35,
#    u'song': [u'Drunk in Love'],
#    u'songurl': [u'/wiki/Drunk_in_Love'],
#    u'titletext': u'"Drunk in Love"',
#    u'url': [u'/wiki/Beyonc%C3%A9', u'/wiki/Jay-Z']},
#   {u'band_singer': [u'Nicki Minaj'],
#    u'ranking': 36,
#    u'song': [u'Anaconda'],
#    u'songurl': [u'/wiki/Anaconda_(Nicki_Minaj_song)'],
#    u'titletext': u'"Anaconda"',
#    u'url': [u'/wiki/Nicki_Minaj']},
#   {u'band_singer': [u'Ariana Grande', u'Zedd'],
#    u'ranking': 37,
#    u'song': [u'Break Free'],
#    u'songurl': [u'/wiki/Break_Free_(Ariana_Grande_song)'],
#    u'titletext': u'"Break Free"',
#    u'url': [u'/wiki/Ariana_Grande', u'/wiki/Zedd']},
#   {u'band_singer': [u'Enrique Iglesias', u'Descemer Bueno', u'Gente de Zona'],
#    u'ranking': 38,
#    u'song': [u'Bailando'],
#    u'songurl': [u'/wiki/Bailando_(Enrique_Iglesias_song)'],
#    u'titletext': u'"Bailando"',
#    u'url': [u'/wiki/Enrique_Iglesias',
#     u'/wiki/Descemer_Bueno',
#     u'/wiki/Gente_de_Zona']},
#   {u'band_singer': [u'Ellie Goulding'],
#    u'ranking': 39,
#    u'song': [u'Burn'],
#    u'songurl': [u'/wiki/Burn_(Ellie_Goulding_song)'],
#    u'titletext': u'"Burn"',
#    u'url': [u'/wiki/Ellie_Goulding']},
#   {u'band_singer': [u'Jason Derulo', u'Snoop Dogg'],
#    u'ranking': 40,
#    u'song': [u'Wiggle'],
#    u'songurl': [u'/wiki/Wiggle_(song)'],
#    u'titletext': u'"Wiggle"',
#    u'url': [u'/wiki/Jason_Derulo', u'/wiki/Snoop_Dogg']},
#   {u'band_singer': [u'Clean Bandit', u'Jess Glynne'],
#    u'ranking': 41,
#    u'song': [u'Rather Be'],
#    u'songurl': [u'/wiki/Rather_Be_(Clean_Bandit_song)'],
#    u'titletext': u'"Rather Be"',
#    u'url': [u'/wiki/Clean_Bandit', u'/wiki/Jess_Glynne']},
#   {u'band_singer': [u'Jeremih', u'YG'],
#    u'ranking': 42,
#    u'song': [u"Don't Tell 'Em"],
#    u'songurl': [u'/wiki/Don%27t_Tell_%27Em'],
#    u'titletext': u'"Don\'t Tell \'Em"',
#    u'url': [u'/wiki/Jeremih', u'/wiki/YG_(rapper)']},
#   {u'band_singer': [u'Kid Ink', u'Chris Brown'],
#    u'ranking': 43,
#    u'song': [u'Show Me'],
#    u'songurl': [u'/wiki/Show_Me_(Kid_Ink_song)'],
#    u'titletext': u'"Show Me"',
#    u'url': [u'/wiki/Kid_Ink', u'/wiki/Chris_Brown']},
#   {u'band_singer': [u'Miley Cyrus'],
#    u'ranking': 44,
#    u'song': [u'Wrecking Ball'],
#    u'songurl': [u'/wiki/Wrecking_Ball_(Miley_Cyrus_song)'],
#    u'titletext': u'"Wrecking Ball"',
#    u'url': [u'/wiki/Miley_Cyrus']},
#   {u'band_singer': [u'Justin Timberlake'],
#    u'ranking': 45,
#    u'song': [u'Not a Bad Thing'],
#    u'songurl': [u'/wiki/Not_a_Bad_Thing'],
#    u'titletext': u'"Not a Bad Thing"',
#    u'url': [u'/wiki/Justin_Timberlake']},
#   {u'band_singer': [u'Katy Perry'],
#    u'ranking': 46,
#    u'song': [u'Roar'],
#    u'songurl': [u'/wiki/Roar_(song)'],
#    u'titletext': u'"Roar"',
#    u'url': [u'/wiki/Katy_Perry']},
#   {u'band_singer': [u'Paramore'],
#    u'ranking': 47,
#    u'song': [u"Ain't It Fun"],
#    u'songurl': [u'/wiki/Ain%27t_It_Fun_(Paramore_song)'],
#    u'titletext': u'"Ain\'t It Fun"',
#    u'url': [u'/wiki/Paramore']},
#   {u'band_singer': [u'Aloe Blacc'],
#    u'ranking': 48,
#    u'song': [u'The Man'],
#    u'songurl': [u'/wiki/The_Man_(Aloe_Blacc_song)'],
#    u'titletext': u'"The Man"',
#    u'url': [u'/wiki/Aloe_Blacc']},
#   {u'band_singer': [u'Florida Georgia Line', u'Luke Bryan'],
#    u'ranking': 49,
#    u'song': [u'This Is How We Roll'],
#    u'songurl': [u'/wiki/This_Is_How_We_Roll'],
#    u'titletext': u'"This Is How We Roll"',
#    u'url': [u'/wiki/Florida_Georgia_Line', u'/wiki/Luke_Bryan']},
#   {u'band_singer': [u'MKTO'],
#    u'ranking': 50,
#    u'song': [u'Classic'],
#    u'songurl': [u'/wiki/Classic_(MKTO_song)'],
#    u'titletext': u'"Classic"',
#    u'url': [u'/wiki/MKTO']},
#   {u'band_singer': [u'Coldplay'],
#    u'ranking': 51,
#    u'song': [u'A Sky Full of Stars'],
#    u'songurl': [u'/wiki/A_Sky_Full_of_Stars'],
#    u'titletext': u'"A Sky Full of Stars"',
#    u'url': [u'/wiki/Coldplay']},
#   {u'band_singer': [u'Ed Sheeran'],
#    u'ranking': 52,
#    u'song': [u"Don't"],
#    u'songurl': [u'/wiki/Don%27t_(Ed_Sheeran_song)'],
#    u'titletext': u'"Don\'t"',
#    u'url': [u'/wiki/Ed_Sheeran']},
#   {u'band_singer': [u'Trey Songz'],
#    u'ranking': 53,
#    u'song': [u'Na Na'],
#    u'songurl': [u'/wiki/Na_Na_(song)'],
#    u'titletext': u'"Na Na"',
#    u'url': [u'/wiki/Trey_Songz']},
#   {u'band_singer': [u'Bobby Shmurda'],
#    u'ranking': 54,
#    u'song': [u'Hot Boy'],
#    u'songurl': [u'/wiki/Hot_Nigga'],
#    u'titletext': u'"Hot Boy"',
#    u'url': [u'/wiki/Bobby_Shmurda']},
#   {u'band_singer': [u'Drake', u'Majid Jordan'],
#    u'ranking': 55,
#    u'song': [u"Hold On, We're Going Home"],
#    u'songurl': [u'/wiki/Hold_On,_We%27re_Going_Home'],
#    u'titletext': u'"Hold On, We\'re Going Home"',
#    u'url': [u'/wiki/Drake_(rapper)', u'/wiki/Majid_Jordan']},
#   {u'band_singer': [u'Ed Sheeran'],
#    u'ranking': 56,
#    u'song': [u'Sing'],
#    u'songurl': [u'/wiki/Sing_(Ed_Sheeran_song)'],
#    u'titletext': u'"Sing"',
#    u'url': [u'/wiki/Ed_Sheeran']},
#   {u'band_singer': [u'Imagine Dragons'],
#    u'ranking': 57,
#    u'song': [u'Radioactive'],
#    u'songurl': [u'/wiki/Radioactive_(Imagine_Dragons_song)'],
#    u'titletext': u'"Radioactive"',
#    u'url': [u'/wiki/Imagine_Dragons']},
#   {u'band_singer': [u'YG', u'Jeezy', u'Rich Homie Quan'],
#    u'ranking': 58,
#    u'song': [u'My Hitta'],
#    u'songurl': [u'/wiki/My_Nigga'],
#    u'titletext': u'"My Hitta"',
#    u'url': [u'/wiki/YG_(rapper)', u'/wiki/Jeezy', u'/wiki/Rich_Homie_Quan']},
#   {u'band_singer': [u'Echosmith'],
#    u'ranking': 59,
#    u'song': [u'Cool Kids'],
#    u'songurl': [u'/wiki/Cool_Kids_(Echosmith_song)'],
#    u'titletext': u'"Cool Kids"',
#    u'url': [u'/wiki/Echosmith']},
#   {u'band_singer': [u'Avicii'],
#    u'ranking': 60,
#    u'song': [u'Hey Brother'],
#    u'songurl': [u'/wiki/Hey_Brother'],
#    u'titletext': u'"Hey Brother"',
#    u'url': [u'/wiki/Avicii']},
#   {u'band_singer': [u'Jason Derulo'],
#    u'ranking': 61,
#    u'song': [u'Trumpets'],
#    u'songurl': [u'/wiki/Trumpets_(Jason_Derulo_song)'],
#    u'titletext': u'"Trumpets"',
#    u'url': [u'/wiki/Jason_Derulo']},
#   {u'band_singer': [u'Maroon 5'],
#    u'ranking': 62,
#    u'song': [u'Animals'],
#    u'songurl': [u'/wiki/Animals_(Maroon_5_song)'],
#    u'titletext': u'"Animals"',
#    u'url': [u'/wiki/Maroon_5']},
#   {u'band_singer': [u'Jason Aldean'],
#    u'ranking': 63,
#    u'song': [u"Burnin' It Down"],
#    u'songurl': [u'/wiki/Burnin%27_It_Down'],
#    u'titletext': u'"Burnin\' It Down"',
#    u'url': [u'/wiki/Jason_Aldean']},
#   {u'band_singer': [u'Luke Bryan'],
#    u'ranking': 64,
#    u'song': [u'Play It Again'],
#    u'songurl': [u'/wiki/Play_It_Again_(Luke_Bryan_song)'],
#    u'titletext': u'"Play It Again"',
#    u'url': [u'/wiki/Luke_Bryan']},
#   {u'band_singer': [u'Tinashe', u'ScHoolboy Q'],
#    u'ranking': 65,
#    u'song': [u'2 On'],
#    u'songurl': [u'/wiki/2_On'],
#    u'titletext': u'"2 On"',
#    u'url': [u'/wiki/Tinashe', u'/wiki/ScHoolboy_Q']},
#   {u'band_singer': [u'Florida Georgia Line'],
#    u'ranking': 66,
#    u'song': [u'Dirt'],
#    u'songurl': [u'/wiki/Dirt_(Florida_Georgia_Line_song)'],
#    u'titletext': u'"Dirt"',
#    u'url': [u'/wiki/Florida_Georgia_Line']},
#   {u'band_singer': [u'OneRepublic'],
#    u'ranking': 67,
#    u'song': [u'Love Runs Out'],
#    u'songurl': [u'/wiki/Love_Runs_Out'],
#    u'titletext': u'"Love Runs Out"',
#    u'url': [u'/wiki/OneRepublic']},
#   {u'band_singer': [u'Brantley Gilbert'],
#    u'ranking': 68,
#    u'song': [u'Bottoms Up'],
#    u'songurl': [u'/wiki/Bottoms_Up_(Brantley_Gilbert_song)'],
#    u'titletext': u'"Bottoms Up"',
#    u'url': [u'/wiki/Brantley_Gilbert']},
#   {u'band_singer': [u'Becky G'],
#    u'ranking': 69,
#    u'song': [u'Shower'],
#    u'songurl': [u'/wiki/Shower_(song)'],
#    u'titletext': u'"Shower"',
#    u'url': [u'/wiki/Becky_G']},
#   {u'band_singer': [u'Rixton'],
#    u'ranking': 70,
#    u'song': [u'Me and My Broken Heart'],
#    u'songurl': [u'/wiki/Me_and_My_Broken_Heart'],
#    u'titletext': u'"Me and My Broken Heart"',
#    u'url': [u'/wiki/Rixton_(band)']},
#   {u'band_singer': [u'Martin Garrix'],
#    u'ranking': 71,
#    u'song': [u'Animals'],
#    u'songurl': [u'/wiki/Animals_(Martin_Garrix_composition)'],
#    u'titletext': u'"Animals"',
#    u'url': [u'/wiki/Martin_Garrix']},
#   {u'band_singer': [u'Rich Gang', u'Young Thug', u'Rich Homie Quan'],
#    u'ranking': 72,
#    u'song': [u'Lifestyle'],
#    u'songurl': [u'/wiki/Lifestyle_(song)'],
#    u'titletext': u'"Lifestyle"',
#    u'url': [u'/wiki/Rich_Gang',
#     u'/wiki/Young_Thug',
#     u'/wiki/Rich_Homie_Quan']},
#   {u'band_singer': [u'Kenny Chesney'],
#    u'ranking': 73,
#    u'song': [u'American Kids'],
#    u'songurl': [u'/wiki/American_Kids'],
#    u'titletext': u'"American Kids"',
#    u'url': [u'/wiki/Kenny_Chesney']},
#   {u'band_singer': [u'Sara Bareilles'],
#    u'ranking': 74,
#    u'song': [u'Brave'],
#    u'songurl': [u'/wiki/Brave_(Sara_Bareilles_song)'],
#    u'titletext': u'"Brave"',
#    u'url': [u'/wiki/Sara_Bareilles']},
#   {u'band_singer': [u'The Neighbourhood'],
#    u'ranking': 75,
#    u'song': [u'Sweater Weather'],
#    u'songurl': [u'/wiki/Sweater_Weather'],
#    u'titletext': u'"Sweater Weather"',
#    u'url': [u'/wiki/The_Neighbourhood']},
#   {u'band_singer': [u'Sam Hunt'],
#    u'ranking': 76,
#    u'song': [u'Leave the Night On'],
#    u'songurl': [u'/wiki/Leave_the_Night_On'],
#    u'titletext': u'"Leave the Night On"',
#    u'url': [u'/wiki/Sam_Hunt']},
#   {u'band_singer': [u'Chris Brown', u'Usher', u'Rick Ross'],
#    u'ranking': 77,
#    u'song': [u'New Flame'],
#    u'songurl': [u'/wiki/New_Flame'],
#    u'titletext': u'"New Flame"',
#    u'url': [u'/wiki/Chris_Brown',
#     u'/wiki/Usher_(musician)',
#     u'/wiki/Rick_Ross']},
#   {u'band_singer': [u'Michael Jackson', u'Justin Timberlake'],
#    u'ranking': 78,
#    u'song': [u'Love Never Felt So Good'],
#    u'songurl': [u'/wiki/Love_Never_Felt_So_Good'],
#    u'titletext': u'"Love Never Felt So Good"',
#    u'url': [u'/wiki/Michael_Jackson', u'/wiki/Justin_Timberlake']},
#   {u'band_singer': [u'Dierks Bentley'],
#    u'ranking': 79,
#    u'song': [u'Drunk on a Plane'],
#    u'songurl': [u'/wiki/Drunk_on_a_Plane'],
#    u'titletext': u'"Drunk on a Plane"',
#    u'url': [u'/wiki/Dierks_Bentley']},
#   {u'band_singer': [u'Katy Perry'],
#    u'ranking': 80,
#    u'song': [u'Birthday'],
#    u'songurl': [u'/wiki/Birthday_(Katy_Perry_song)'],
#    u'titletext': u'"Birthday"',
#    u'url': [u'/wiki/Katy_Perry']},
#   {u'band_singer': [u'Lady Antebellum'],
#    u'ranking': 81,
#    u'song': [u'Bartender'],
#    u'songurl': [u'/wiki/Bartender_(Lady_Antebellum_song)'],
#    u'titletext': u'"Bartender"',
#    u'url': [u'/wiki/Lady_Antebellum']},
#   {u'band_singer': [u'Naughty Boy', u'Sam Smith'],
#    u'ranking': 82,
#    u'song': [u'La La La'],
#    u'songurl': [u'/wiki/La_La_La_(Naughty_Boy_song)'],
#    u'titletext': u'"La La La"',
#    u'url': [u'/wiki/Naughty_Boy', u'/wiki/Sam_Smith_(singer)']},
#   {u'band_singer': [u'Robin Thicke', u'T.I.', u'Pharrell Williams'],
#    u'ranking': 83,
#    u'song': [u'Blurred Lines'],
#    u'songurl': [u'/wiki/Blurred_Lines'],
#    u'titletext': u'"Blurred Lines"',
#    u'url': [u'/wiki/Robin_Thicke', u'/wiki/T.I.', u'/wiki/Pharrell_Williams']},
#   {u'band_singer': [u'Lady Gaga', u'R. Kelly'],
#    u'ranking': 84,
#    u'song': [u'Do What U Want'],
#    u'songurl': [u'/wiki/Do_What_U_Want'],
#    u'titletext': u'"Do What U Want"',
#    u'url': [u'/wiki/Lady_Gaga', u'/wiki/R._Kelly']},
#   {u'band_singer': [u'Shakira', u'Rihanna'],
#    u'ranking': 85,
#    u'song': [u"Can't Remember to Forget You"],
#    u'songurl': [u'/wiki/Can%27t_Remember_to_Forget_You'],
#    u'titletext': u'"Can\'t Remember to Forget You"',
#    u'url': [u'/wiki/Shakira', u'/wiki/Rihanna']},
#   {u'band_singer': [u'5 Seconds of Summer'],
#    u'ranking': 86,
#    u'song': [u'Amnesia'],
#    u'songurl': [u'/wiki/Amnesia_(5_Seconds_of_Summer_song)'],
#    u'titletext': u'"Amnesia"',
#    u'url': [u'/wiki/5_Seconds_of_Summer']},
#   {u'band_singer': [u'T.I.', u'Iggy Azalea'],
#    u'ranking': 87,
#    u'song': [u'No Mediocre'],
#    u'songurl': [u'/wiki/No_Mediocre'],
#    u'titletext': u'"No Mediocre"',
#    u'url': [u'/wiki/T.I.', u'/wiki/Iggy_Azalea']},
#   {u'band_singer': [u'KONGOS'],
#    u'ranking': 88,
#    u'song': [u'Come with Me Now'],
#    u'songurl': [u'/wiki/Come_with_Me_Now'],
#    u'titletext': u'"Come with Me Now"',
#    u'url': [u'/wiki/Kongos_(band)']},
#   {u'band_singer': [u'Lil Wayne', u'Drake'],
#    u'ranking': 89,
#    u'song': [u'Believe Me'],
#    u'songurl': [u'/wiki/Believe_Me_(Lil_Wayne_song)'],
#    u'titletext': u'"Believe Me"',
#    u'url': [u'/wiki/Lil_Wayne', u'/wiki/Drake_(rapper)']},
#   {u'band_singer': [u'Mike WiLL Made-It',
#     u'Miley Cyrus',
#     u'Wiz Khalifa',
#     u'Juicy J'],
#    u'ranking': 90,
#    u'song': [u'23'],
#    u'songurl': [u'/wiki/23_(song)'],
#    u'titletext': u'"23"',
#    u'url': [u'/wiki/Mike_Will_Made_It',
#     u'/wiki/Miley_Cyrus',
#     u'/wiki/Wiz_Khalifa',
#     u'/wiki/Juicy_J']},
#   {u'band_singer': [u'Jake Owen'],
#    u'ranking': 91,
#    u'song': [u"Beachin'"],
#    u'songurl': [u'/wiki/Beachin%27'],
#    u'titletext': u'"Beachin\'"',
#    u'url': [u'/wiki/Jake_Owen']},
#   {u'band_singer': [u'Macklemore & Ryan Lewis', u'ScHoolboy Q', u'Hollis'],
#    u'ranking': 92,
#    u'song': [u'White Walls'],
#    u'songurl': [u'/wiki/White_Walls'],
#    u'titletext': u'"White Walls"',
#    u'url': [u'/wiki/Macklemore_%26_Ryan_Lewis',
#     u'/wiki/ScHoolboy_Q',
#     u'/wiki/Hollis_(singer)']},
#   {u'band_singer': [u'5 Seconds of Summer'],
#    u'ranking': 93,
#    u'song': [u'She Looks So Perfect'],
#    u'songurl': [u'/wiki/She_Looks_So_Perfect'],
#    u'titletext': u'"She Looks So Perfect"',
#    u'url': [u'/wiki/5_Seconds_of_Summer']},
#   {u'band_singer': [u'Zedd', u'Hayley Williams'],
#    u'ranking': 94,
#    u'song': [u'Stay the Night'],
#    u'songurl': [u'/wiki/Stay_the_Night_(Zedd_song)'],
#    u'titletext': u'"Stay the Night"',
#    u'url': [u'/wiki/Zedd', u'/wiki/Hayley_Williams']},
#   {u'band_singer': [u'Beyonc\xe9'],
#    u'ranking': 95,
#    u'song': [u'Partition'],
#    u'songurl': [u'/wiki/Partition_(song)'],
#    u'titletext': u'"Partition"',
#    u'url': [u'/wiki/Beyonc%C3%A9']},
#   {u'band_singer': [u'ScHoolboy Q', u'BJ the Chicago Kid'],
#    u'ranking': 96,
#    u'song': [u'Studio'],
#    u'songurl': [u'/wiki/Studio_(song)'],
#    u'titletext': u'"Studio"',
#    u'url': [u'/wiki/ScHoolboy_Q', u'/wiki/BJ_the_Chicago_Kid']},
#   {u'band_singer': [u'Drake'],
#    u'ranking': 97,
#    u'song': [u'0 to 100', u'The Catch Up'],
#    u'songurl': [u'/wiki/0_to_100_/_The_Catch_Up'],
#    u'titletext': u'"0 to 100 / The Catch Up"',
#    u'url': [u'/wiki/Drake_(rapper)']},
#   {u'band_singer': [u'Lee Brice'],
#    u'ranking': 98,
#    u'song': [u"I Don't Dance"],
#    u'songurl': [u'/wiki/I_Don%27t_Dance_(Lee_Brice_song)'],
#    u'titletext': u'"I Don\'t Dance"',
#    u'url': [u'/wiki/Lee_Brice']},
#   {u'band_singer': [u'Miranda Lambert', u'Carrie Underwood'],
#    u'ranking': 99,
#    u'song': [u"Somethin' Bad"],
#    u'songurl': [u'/wiki/Somethin%27_Bad'],
#    u'titletext': u'"Somethin\' Bad"',
#    u'url': [u'/wiki/Miranda_Lambert', u'/wiki/Carrie_Underwood']},
#   {u'band_singer': [u'Miley Cyrus'],
#    u'ranking': 100,
#    u'song': [u'Adore You'],
#    u'songurl': [u'/wiki/Adore_You_(Miley_Cyrus_song)'],
#    u'titletext': u'"Adore You"',
#    u'url': [u'/wiki/Miley_Cyrus']}]}

# %% [markdown]
# ### Construct a year-song-singer dataframe from the yearly information

# %% [markdown]
# Let's construct a dataframe from the `yearinfo`. Pandas DataFrames are like Excel spreadsheets or CSV files. They are great for representing data that has the same data type on each column, but different types across columns. However, if you look at the data structure we have so far, a given key can have a list of values with multiple entries. Also, our data is grouped by year. So we need a way to flatten this data into a format that will create a useful DataFrame.

# %% [markdown]
# #### Construct a panel and flatten it

# %% [markdown]
# To do this, we iterate over the years and the singles per year. For each single, we then iterate over singers and songs, in the end constructing a dataframe for each year. This dataframe has one row per single/singer/song combination. We can then store these dataframes into a dictionary, construct a Panel from it (look it up in the Pandas docs), and flatten the panel to get a hierarchically indexed dataframe.
#
# A Panel is a 3-D version of a DataFrame, or a DataFrame of DataFrames. Think of dataframes stacked on top of each other and coming out of the screen. We then flatten this Panel into a single Dataframe by using Pandas ability to have hierarchical indexing: in this case its the ranking/year combination that things get flattened under.
#
# Don't worry if you don't get the Panel to DataFrame part. We will have plenty of time to learn about Pandas and its data structures. But make sure you understand the logic of everything before the last three lines.

# %%
yeardict={}
for y in yearinfo.keys():
    yearlist=yearinfo[y]
    yearlist2=[]
    for idict in yearlist:
        singers=idict['band_singer']
        for i,s in enumerate(singers):
            songs=idict['song']
            for j,so in enumerate(songs):#now inside each singer song combination
                nd={}
                nd['band_singer']=s
                nd['url']=idict['url'][i]
                nd['song']=so
                nd['songurl']=idict['songurl'][j]
                nd['ranking']=idict['ranking']
                yearlist2.append(nd)
    yeardict[y]=pd.DataFrame(yearlist2)#one for each year
yearspanel=pd.Panel.from_dict(yeardict, orient="minor")#stack dataframes into a panel
hierframe=yearspanel.to_frame() #flattening leads to a hierarchical index

# %%
hierframe.head()

# %% [markdown]
# We really want a non-hierarchical dataframe. So, let's flatten the dataframe further and rename some of the items in the index to create a non-hierarchically indexed dataframe.

# %%
flatframe = hierframe.reset_index()
flatframe.head()

# %%
flatframe = flatframe.rename(columns={'minor':'year'})
del flatframe['major']
flatframe.head(8)

# %% [markdown]
# #### Cleaning data: the correct datatypes

# %% [markdown]
# Now let's check if the DataFrame has the right data types.

# %%
flatframe.dtypes

# %% [markdown]
# Pandas treats strings as generic objects, so most fields look right. However, in **1.1** we used the _range_ function to create the years, which means our dictionary should have integer keys, which should in turn become integer values on the DataFrame. What gives (hint: everything looked right until we restored the data from the JSON file)?

# %% [markdown]
# We should fix that. We use the [astype](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.astype.html) function to transform the data on the _year_ column from string to integer.

# %%
flatframe.year = flatframe.year.astype(int)
flatframe.dtypes

# %% [markdown]
# ## Q2. Scraping and Constructing: Information about Artists, Bands and Genres from Wikipedia

# %% [markdown]
# Our next job is to use those singer urls and get information about singers and/or bands. Here is an example.

# %%
for th in pq(requests.get("http://en.wikipedia.org/wiki/Jason_Derulo").text)(".infobox tr th"):
    if pq(th).text() == "Genres":
        for e in pq(th).nextAll("td li a"):
            if pq(e).attr.href.find("#cite_note") == -1:
                print pq(e).attr.href, pq(e).attr.title

# %% [markdown]
# ### Scrape information about artists from wikipedia

# %% [markdown]
# We wish to fetch information about the singers or groups for all the winning songs in a list of years.
#
# Here we show a function that fetches information about a singer or group from their url on wikipedia. The function uses a `requests` call.
#
# If the request gets an HTTP code different from 200, the cells for that URL will have a value of 1; and if the request completely fails (e.g. no network connection) the cell will have a value of 2. This will allow you to analyse the failed requests.
#
# Notice that we have wrapped the call in whats called _an exception block_. We try to make the request. If it fails entirely, or returns a HTTP code thats not 200, we set the status to 2 and 1 respectively.
#
# We also create a cache object `urlcache` that will avoid redundant HTTP requests (e.g. an artist might have multiple singles on a single year, or be on the list over a span of years). Remember that this function is designed to be used in a loop over years, and then a loop over songs per year. It stands to reason that prolific singers or bands will show up again and again. Since network requests are relatively slow, if we have already getched a singer or band's wikipedia page, caching the results is a smart thing to do.
#
# For those interested in digging deeper into these types of optimization, check out _memoization_ techniques, and the _lru_cache_ function on the _functools_ package.

# %%
urlcache={}

# %%
def get_page(url):
    # Check if URL has already been visited.
    if (url not in urlcache) or (urlcache[url]==1) or (urlcache[url]==2):
        time.sleep(1)
        # try/except blocks are used whenever the code could generate an exception (e.g. division by zero).
        # In this case we don't know if the page really exists, or even if it does, if we'll be able to reach it.
        try:
            r = requests.get("http://en.wikipedia.org%s" % url)

            if r.status_code == 200:
                urlcache[url] = r.text
            else:
                urlcache[url] = 1
        except:
            urlcache[url] = 2
    return urlcache[url]

# %% [markdown]
# We sort the `flatframe` by year, ascending, first. Why? It ensures that we will hit the cache most as singers who show up repeatedly in the rankings will have their information already pulled.

# %%
flatframe=flatframe.sort('year')

# %% [markdown]
# #### Pulling and saving the data

# %% [markdown]
# **Note**: the function below takes a fair bit of time, about 25 minutes, for me.

# %%
# Here we are populating the url cache
# subsequent calls to this cell should be very fast, since Python won't
# need to fetch the page from the web server.
#NOTE this function will take quite some time to run (about 25 mins for me), since we sleep 1 second before
#making a request. If you run it again it will be almost instantaneous, save requests that might have failed
#(you will need to run it again if requests fail..see cell below for how to test this)
flatframe["url"].apply(get_page)

# %% [markdown]
# You may have to run this function again and again, incase there were network problems and such. Notice that because there is a "global" cache, it will take less time each time you run it. Also note that this function is designed to be run again and again: it just tries to make sure that there are no unresolved pages left. Let us make sure of this: *the sum below should be 0, and the boolean True.*

# %%
print np.sum([(urlcache[k]==1) or (urlcache[k]==2) for k in urlcache])# no one or 0's
print len(flatframe.url.unique())==len(urlcache)#we got all of the urls

# %% [markdown]
# Let's save the `urlcache` to disk and remove the old object.

# %%
with open("tempdata/artistinfo.json","w") as fd:
    json.dump(urlcache, fd)
del urlcache

# %% [markdown]
# Now let's reload the dictionary from the JSON file.

# %%
with open("tempdata/artistinfo.json") as json_file:
    urlcache = json.load(json_file)

# %% [markdown]
# #### 2.1 Extract information about singers and bands

# %% [markdown]
# From each page we collected about a singer or a band, extract the following information:
#
# 1. The genres that the band or singer works in (sidebar on right). These genres should be urls, this ensures their uniqueness. Create a list of these urls `genres`. If no genres, use `['NA']`.
#
# 2. If the page has the text "Born" in the sidebar on the right, extract the element with the class `.bday`. If no "Born", store `False`. Store either of these into the variable `born`. We want to analyze the artist's age.
#
# 3. If the text "Years active" is found, but no "born", assume a band. Store into the variable `ya` the value of the next table cell corresponding to this, or `False` if the text is not found.
#
# Put this all into a function `singer_band_info` which takes the singer/band url as argument and returns a dictionary `dict(url=url, genres=genres, born=born, ya=ya)`.
#
# The information can be found on the sidebar on each such wikipedia page, as the example here shows:
#
# ![sandg](sandg.png).
#
# Once again, we can use the developer tools to divulge the structure of the web page:
#
# ![diana](dianaross.png)

# %% [markdown]
# Please write the function `singer_band_info` according to the following specification:

# %%
"""
Function
--------
singer_band_info

Inputs
------
url: the url
page_text: the text associated with the url
   
Returns
-------
A dictionary with the following data:
    url: copy the input argument url into this value
    genres: the genres that the band or singer works in
    born: the artist's birthday
    ya: years active variable

Notes
-----
See description above. Also note that some of the genres urls might require a 
bit of care and special handling.
"""

#your code here

# %% [markdown]
# #### Merging this information in

# %% [markdown]
# Let's iterate over the items in the singer-group dictionary cache `urlcache`, run the above function, and create a dataframe from there.

# %%
singer_band_info_list=[]
for k,v in urlcache.items():
    singer_band_info_list.append(singer_band_info(k, v))

# %%
tempdf=pd.DataFrame(singer_band_info_list)
tempdf.head()

# %% [markdown]
# We merge the artist/song data frames into one large dataframe. Note that this has an effect of imputing to a song **all the genres** that the artist is active in. We know that this is not true, but it is the simplest assumption we can make, and is probably good for most artists. (To think: how might you check this?)

# %%
largedf=flatframe.merge(tempdf, on="url")
largedf.head()

# %% [markdown]
# #### 2.2 Split out the genres

# %% [markdown]
# Update the dataframe by adding a column for each genre with true-false encoding for each row. This means, we want columns like "/wiki/Acid_house", "/wiki/Acid_jazz", where if an artist is in that genre, the dataframe cell has a python boolean, `True`. Otherwise, it has a `False`.
#
# Remember that an artist/band can be in multiple genres, and must have a "True" for each column corresponding to these genres, and false otherwise.
#
# This will widen the dataframe by the total number of genres that we have. The expanded part will look a bit like this:
#
# ![expansion](expandingframe.png)
#
# HINT: for example code see http://nbviewer.ipython.org/github/cs109/content/blob/master/lec_04_wrangling.ipynb, a notebook which lays out a very nice rubric for data analysis.

# %%
#your code here

# %% [markdown]
# ## Q3. Exploratory Data Analysis (EDA)

# %% [markdown]
# At this point we have one dataframe `flatframe` for the songs, and one merged dataframe which has the songs with artist info in each row for each song, `largedf`.
#
# Our first visualization is an attempt to answer the following question:

# %% [markdown]
# ### What has been the trajectory of various genres in the popular zeitgeist?

# %% [markdown]
# We will use the trends in the Billboard top 100 as evidence. To that goal, let us see which are the 24 most popular genres.

# %% [markdown]
# To do this, we calculate the mean of the dataframe and eliminate the first two columns (`year` and `ranking`) to get means of all the genre columns. We sort it in ascending order, multiply by 100 to get percentages, and pick the top 24.

# %%
# Get the mean of all the *numerical* values, over the column axis (0).
# This works because True is numerically equal to 1 in Python (e.g. True + True == 2)
# so mean sums up the trues and divides by the total
#and it only does it for numerical columns
genrefrac = largedf.mean(axis=0)*100
# The first two numerical values are ranking and year, so start from the third.
genrefrac = genrefrac[2:]
# Sort the values in descending order (note that the sort method changed the list in place).
#This is because its a series sort. Pandas Dataframe sorts, the type we used earlier, do not
#do the sort in place.
genrefrac.sort(ascending=False)
# Get the first 24 items.
genrefrac[:24]

# %% [markdown]
# ####3.1 Plot a horizontal bar chart of the top 30 genres

# %% [markdown]
# You will have to change the index of the `genrefrac` series to strip `/wiki` from the genre names, and convert underscores to spaces. **Hint**: Use the pandas `plot`, `reset_index` and `set_index` methods. Label the y-axis "Genres".

# %%
#your code here

# %% [markdown]
# Lets take the top 24 genres from `genrefrac`. For each genre, we create a subframe of the ranking and year from those rows for which that genre is "True". We group the resulting dataframe by year. We obtain a dictionary `genreinfo` keyed by genre, whose value is a tuple of 3 Pandas series: the mean rankings per year for that genre, the standard deviation on those rankings, and the series groupby object for the rankings per year.

# %%
genreinfo={}
topgenres=genrefrac.index[:24]
for genre in topgenres:
    genreframe=largedf[largedf[genre]==True][['ranking','year']]
    ggby = genreframe.groupby('year')
    genreinfo[genre]={'meanseries': ggby['ranking'].mean(), 'stdseries': ggby['ranking'].std(), 'rankingseries': ggby['ranking']}
genreinfo['/wiki/Funk']

# %% [markdown]
# Notice that there are NaN's in the standard deviations. Pandas calculates standard deviations for samples rather than populations, and if there is only 1 item, then the standard deviation calculation involves a division by 0.

# %% [markdown]
# #### 3.2 Make a small multiples plot of the 24 most popular genres

# %% [markdown]
# Make a 8 row, 3 column small multiples plot with elements like:
#
# ![Small Multiple](smmult.png)
#
# You will use `genreinfo`, which we just computed, to make a plot of how the "ranking of a genre" has changed with time. The mean rank achieved by songs in a genre forms the backbone of this plot, with the standard deviation shown, and rankings of all the songs in the genre that year shown as well, at a very low transparency. (Since a song belongs to many genres through the artist, this means that a song may be represented in multiple plots. Again, while not strictly true, this is a simplifying assumption we are making.)
#
# Some instructions for the plot:
#
# 1. The blue scatters are all the songs "in" that genre: keep them at a low alpha so one can visually see the density.
# 2. The dark red points are the means. You can choose to join them if you like.
# 3. The light red band uses matplotlib's `fill_between` to fill the area between `mean-std` and `mean+std`.
# 4. If the standard deviation is NaN, fill up the entire y dimension with it to give a notion of large impreciseness in the measure.
#
# HINT: Once again, http://nbviewer.ipython.org/github/cs109/content/blob/master/lec_04_wrangling.ipynb may help in creating such a plot.
#
# If you have a better viz for this, by all means go for it!

# %%
#your code here

# %% [markdown]
# **3.2(contd) What trends do you see?**
#
# Write a paragraph or two, touching on which genres are the most popular, and how this popularity has changed over time.

# %% [markdown]
# *your answer here*

# %% [markdown]
# ### Who are the highest quality singers?

# %% [markdown]
# Here we show the highest quality singers and plot them on a bar chart.
#
# What do we mean by highest quality? This is of-course open to interpretation, but lets define "highest quality" here as the number of times a singer appears in the top 100 over this time period. If they appear twice in a year(for different songs), this is counted as two appearances, not one. We cut our chart of at those singers who have appeared more than 15 times.

# %%
prolific=flatframe.url.value_counts()
prolific[prolific > 15].plot(kind="barh");

# %% [markdown]
# #### 3.3 What if we used a different metric?

# %% [markdown]
# What we would like to capture is this: a singer ought to be scored higher if he or she appears higher in the rankings. So we'd say that a singer who appeared once at a higher and once at a lower ranking is a "higher quality" singer than one who appeared twice at a lower ranking.
#
# To do this, group all of a singers songs together and assign each song a score `101 - ranking`. Order the singers by their total score and make a bar chart for the top 20.

# %%
#your code here

# %% [markdown]
# **3.3(contd)Do you notice any major differences when you change the metric?**
#
# How have the singers at the top shifted places? Why do you think this is so?

# %% [markdown]
# *your answer here*

# %% [markdown]
# #### The age at which singers achieve their top ranking.

# %% [markdown]
# As an example to warm you up for the next question, we plot a histogram of the age at which singers achieve their top ranking

# %%
dfb=largedf[largedf.born!=False][['year','born','ranking','url']]
dfb['byear']=dfb.born.apply(lambda x: int(x.split('-')[0]))
byurl=dfb.groupby('url')
frames=[]
for k, v in byurl:
    minr=v.ranking.min()
    frames.append(v[v.ranking==minr])
topscoresdf=pd.concat(frames)
(topscoresdf.year-topscoresdf.byear).hist(bins=np.arange(10,70,5), normed=True);

# %% [markdown]
# The *age of first fame* has an interesting shape, unimodal with a mode in the late 20s with a long tail to the right. This makes sense because there really is a lower age limit to artists but not so much an upper one. So you expect this type of behavior.

# %% [markdown]
# #### 3.4 At what year since inception do bands reach their top rankings?

# %% [markdown]
# Make a similar calculation to plot a histogram of the years since inception at which bands reach their top ranking

# %%
#your code here

# %% [markdown]
# ## Q4: Billboard Magazine: year end results from weekly results

# %% [markdown]
# The aim of this problem is to find features in the weekly Billboard top 100 that can predict the end year results. In the interests of time, we'll only do 2014: a complete study would do all the years.
# Let us first fetch the end-of-year results.

# %% [markdown]
# ### Get the end year results, and results from all saturdays of the year.

# %%
end_year=requests.get("http://www.billboard.com/charts/year-end/2014/hot-100-songs").text

# %% [markdown]
# Billboard releases its daily ratings on saturdays.

# %% [markdown]
# We first write a function `allsats(year, fs)` to get all the saturdays in a given year, and given the day part of the date of the first saturday of the year in january. We use the `date` and `timedelta` modules.

# %%
from datetime import date, timedelta

def allsats(year, fs):
    days=[]
    d = date(year, 1, fs)       
    while d.year == year:
        days.append(d.strftime("%Y-%m-%d"))
        d += timedelta(days = 7)
    return days

# %% [markdown]
# The first Saturday in 2014 is Jan 4th:

# %%
sats=allsats(2014, 4)
sats

# %% [markdown]
# #### Get the data

# %% [markdown]
# Let us use `requests` to get the billboard pages for all these days. The format for the data is a dictionary `satdict` with keys the saturday date strings we see above, and one additional key, `end_year`. The values corresponding to the keys are the html text downloaded from billboard. The value corresponding to the `end_year` key comes from the `end_year` variable.
#
# Billboard makes the lists for every saturday available at:
# `http://www.billboard.com/charts/hot-100/saturday`, for example, http://www.billboard.com/charts/hot-100/2014-12-27 .

# %%
satdict={}
satdict['end_year']=end_year
for sat in sats:
    satdict[sat]=requests.get("http://www.billboard.com/charts/hot-100/"+sat).text
    time.sleep(1)

# %% [markdown]
# We save the output in a file, `satdict.json`.

# %%
with open("tempdata/satdict.json","w") as fd:
    json.dump( satdict, fd)
del satdict
with open("tempdata/satdict.json") as fd:
    satdict=json.load(fd)

# %% [markdown]
# #### 4.1 Parse the HTML and save the song information

# %% [markdown]
# Write a function `get_weekly(weekstring, indict)` which takes the string corresponding to a saturday, `weekstring` and a dictionary `indict` with *keys* as the saturdays and *value* as the text of the billboard page for that day. Parse the text, returning a list of tuples `(ranking, songdict)` with a `songdict` dictionary. Each tuple corresponds to a song in that week's top-100, with `ranking` the ranking of that song.
#
# One of these pages looks like this in the developer tools:
#
# ![billboard](billboard.png)
#
# Make the dictionary `songdict` look like this:
#
# `songdict=dict(ranking=ranking, title=title)`
#
# where the title is the title of the song. The `ranking` is the same `ranking` that is the first element of the tuple.

# %%
"""
Function
--------
get_weekly

Inputs
------
weekstring: the saturday in question
indict: a dictionary with keys being saturdays, and values being the billboard html associated
with those saturdays
   
Returns
-------
A list of tuples. Each tuple has two elements. The first element is the ranking. The
second is a dictionary songdict with keys
    ranking: ranking of song. same as first element of the tuple
    title: title of song


Notes
-----
See description above.
"""
#your code here

# %% [markdown]
# Let's process the weekly and year-end information using the function you just defined. We create a `weekinfo` list with the above function run for each week. We also store in the variable `yearend` the results of running the function for the end of year rankings. We `zip` the `weekinfo` together with the saturdays to create a list of tuples `weektuples`.

# %%
weekinfo=[]
for k in sats:
    weekinfo.append(get_weekly(k, satdict))
yearend=get_weekly('end_year', satdict)
weektuples=zip(sats, weekinfo)

# %% [markdown]
# ---
#
# Here we write a function `get_for_title(weektups)` that takes the tuples created above and returns a dictionary `titles` whose *key* is the title of the song, and whose *value* is a list of tuples, the members of which are (`weekindex`, `ranking`). The `weekindex` starts at 1 for the first week of the year, and `ranking` is the ranking achieved that week.

# %%
def get_for_title(weektups):
    titles={}
    weekindex=1
    for weekdate, weeksrankings in weektups:
        for rankingtuple in weeksrankings:#iterate over the week's top-100
            ranking = rankingtuple[0]
            weekdict=rankingtuple[1]
            if not titles.has_key(weekdict['title']):
                titles[weekdict['title']]=[]
            titles[weekdict['title']].append((weekindex, ranking))
        weekindex=weekindex+1
    return titles

# %%
titles = get_for_title(weektuples)

# %% [markdown]
# Now let's create a dictionary keyed by the lower-cased title where we store the rank means (`rankmean`), rank standard deviations (`rankstd`) and rank count, the number of times(weeks) it appeared in the rankings in 2014, (`ranklen`), for a song.

# %%
tdict={}
for title in titles.keys():
    wtlist=titles[title]
    weeks=[e[0] for e in wtlist]
    ranks=[e[1] for e in wtlist]
    rankmean=np.mean(ranks)
    rankstd=np.std(ranks, ddof=1)#numpy standard deviation is population based, make it sample based
    ranklen=len(ranks)
    tdict[title.lower()]={'ranks':(rankmean, rankstd, ranklen)}

# %% [markdown]
# ### Get winning songs, and see how they do in all these weeks

# %% [markdown]
# Now we create a list of winners whose elements are `dict(title, winner=1, ranking=year-end-ranking, rankmean=mean over weeks, rankstd=stddev over weeks, weekson=ranklen)`. To make this, we go to the songs that are in the top 100 at years-end and pick up their information from `tdict` above.

# %%
winners=[]
for yt in yearend:
    r,d =yt
    title=d['title'].lower()
    rvals=tdict[title]['ranks']
    winners.append(dict(title=title, winner=1, ranking=d['ranking'], rankmean=rvals[0], rankstd=rvals[1], weekson=rvals[2]))

# %% [markdown]
# And we use this list of dictionaries to create a dataframe `winners2014` with al the information gathered.

# %%
winners2014=pd.DataFrame(winners)
winners2014.head()

# %% [markdown]
# #### 4.2 Plot the mean rank(y axis) against the final, year-end rank(x-axis)

# %% [markdown]
# Show a 45 degree line for comparison. Use `plt.errorbar` to show the standard deviation along with the mean rank.

# %%
# your code here

# %% [markdown]
# **4.2(contd)Comment on the trend in this plot. **
#
# In a paragraph, tell us how the general trend compares to the 45 degree line? What does this say about the predictive ability of the average rank for the final rank?

# %% [markdown]
# *your answer here*

# %% [markdown]
# ###Add losers in and see what features may be used to distinguish winners from losers

# %% [markdown]
# Let's create a list `losers` of dictionaries, one for each song from the weekly lists that did not make it to the year end list. The dictionaries are identical to the dictionaries in the `winners` list, but we code the `ranking` as -1 for losers and set `winner` to 0. Thus

# %%
winlist=[e['title'] for e in winners]
losers=[]
for title in tdict:
    if not title in winlist:
        rvals=tdict[title]['ranks']
        losers.append(dict(title=title, winner=0, ranking=-1, rankmean=rvals[0], rankstd=rvals[1], weekson=rvals[2]))

# %% [markdown]
# We create a `losers2014` dataframe...

# %%
losers2014=pd.DataFrame(losers)
losers2014.head()

# %% [markdown]
# ...and concatenate the losers and winners into one dataframe.

# %%
all2014=pd.concat([winners2014, losers2014])
all2014.head()

# %% [markdown]
# ####4.3 Make a scatterplot matrix of these features, color coded by winners/losers

# %% [markdown]
# Use `sns.pairplot`. Use all the numerical features(4), with the exception of `winner`, which you will use to give a different color to winners and losers. This will be a 4x4 matrix, with different colored dots for winners and losers off diagonal, and a 2 histograms on diagonal. The histogram shows the distribution of the one feature on the diagonal for both the winners and losers.

# %%
#your code here

# %% [markdown]
# **4.3 (contd) Which combination of "features" is most likely to separate winners from losers? **
#
# It is this kind of observation in EDA that forms the basis for staring on predictive modelling! In a paragraph, identify one or two combinations of features that you think will best separate winners from losers. Why?

# %% [markdown]
# *your answer here*

# %% [markdown]
#  **Until next time.**
